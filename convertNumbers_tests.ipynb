# %% [markdown]
# <a href="https://colab.research.google.com/github/andreac941/ComputerVision-Eq3/blob/main/convertNumbers_tests.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import sys
import time

def convert_numbers(file_path):
    try:
        start_time = time.time()

        with open(file_path, 'r') as file:
            numbers = file.read().split()

            binary_results = []
            hex_results = []

            for number in numbers:
                try:
                    num = int(number)
                    binary_results.append(bin(num)[2:])
                    hex_results.append(hex(num)[2:])
                except ValueError:
                    print(f"Invalid data found: {number}. Skipping.")

        end_time = time.time()
        elapsed_time = end_time - start_time

        print_results(binary_results, hex_results, elapsed_time)
        write_to_file(binary_results, hex_results, elapsed_time)

    except FileNotFoundError:
        print(f"Error: File '{file_path}' not found.")
    except Exception as e:
        print(f"An error occurred: {e}")

def print_results(binary_results, hex_results, elapsed_time):
    print("Binary\t\tHexadecimal")
    print("------\t\t------------")
    for binary, hexa in zip(binary_results, hex_results):
        print(f"{binary}\t\t{hexa}")

    print(f"\nTime elapsed: {elapsed_time:.6f} seconds")

def write_to_file(binary_results, hex_results, elapsed_time):
    with open('ConversionResults.txt', 'w') as result_file:
        result_file.write("Binary\t\tHexadecimal\n")
        result_file.write("------\t\t------------\n")
        for binary, hexa in zip(binary_results, hex_results):
            result_file.write(f"{binary}\t\t{hexa}\n")

        result_file.write(f"\nTime elapsed: {elapsed_time:.6f} seconds")

if __name__ == "__main__":
    if len(sys.argv) != 2:
        print("Usage: python convertNumbers.py fileWithData.txt")
    else:
        input_file = sys.argv[1]
        convert_numbers(input_file)
# Out:
# Usage: python convertNumbers.py fileWithData.txt

# %%
import time

def convert_numbers(file_path):
    try:
        start_time = time.time()

        with open(file_path, 'r') as file:
            content = file.read()
            numbers = content.split()

            binary_results = []
            hex_results = []

            for number in numbers:
                try:
                    num = int(number)
                    binary_results.append(bin(num)[2:])
                    hex_results.append(hex(num)[2:])
                except ValueError:
                    print(f"Invalid data found: {number}. Skipping.")

        end_time = time.time()
        elapsed_time = end_time - start_time

        print_results(binary_results, hex_results, elapsed_time)
        write_to_file(binary_results, hex_results, elapsed_time)

    except FileNotFoundError:
        print(f"Error: File '{file_path}' not found.")
    except Exception as e:
        print(f"An error occurred: {e}")

def print_results(binary_results, hex_results, elapsed_time):
    print("Binary\t\tHexadecimal")
    print("------\t\t------------")
    for binary, hexa in zip(binary_results, hex_results):
        print(f"{binary}\t\t{hexa}")

    print(f"\nTime elapsed: {elapsed_time:.6f} seconds")

def write_to_file(binary_results, hex_results, elapsed_time):
    with open('/content/ConversionResults.txt', 'w') as result_file:
        result_file.write("Binary\t\tHexadecimal\n")
        result_file.write("------\t\t------------\n")
        for binary, hexa in zip(binary_results, hex_results):
            result_file.write(f"{binary}\t\t{hexa}\n")

        result_file.write(f"\nTime elapsed: {elapsed_time:.6f} seconds")

# Assuming you have a file named 'fileWithData.txt' in the Colab files section
input_file_path = '/content/TC2.txt'

# Run the conversion
convert_numbers(input_file_path)
# Out:
# Binary		Hexadecimal
# ------		------------
# 11011001001011111101000		6c97e8
# 110010110110100100100		196d24
# 100001111001101011000111		879ac7
# 11001100111011000101		ccec5
# 11100001101001111000		e1a78
# 11111010100100000110		fa906
# 110001010010110111101		18a5bd
# 100000011101111000011		103bc3
# 10100101110001111011		a5c7b
# 10011110110000000110010		4f6032
# 10010001000000111011		9103b
# 11000011101001011011		c3a5b
# 1110011110111110001110		39ef8e
# 11100100100011010110001		7246b1
# 100101001001111011110100		949ef4
# 100010110100101100100001		8b4b21
# 10100111000010010110111		5384b7
# 100001001100100000000101		84c805
# 11111011011001111100010		7db3e2
# 100001000110111001111110		846e7e
# 1011110001101111000		5e378
# 10110011000011101001100		59874c
# 10010101010111101001110		4aaf4e
# 100010010101001000011011		89521b
# 10000110000011001010111		430657
# 111111011010110110011		1fb5b3
# 1011101101100010101100		2ed8ac
# 11100011011010101011110		71b55e
# 10101011111110110110110		55fdb6
# 100101101010000001100		12d40c
# 10111001110110010001011		5cec8b
# 110110101100100111100		1b593c
# 11000000001110000001101		601c0d
# 1001001011111001100110		24be66
# 100000011101101010010100		81da94
# 11110010000101011101		f215d
# 11000101000000110111011		6281bb
# 11101110111011010110111		7776b7
# 11000001001001001100011		609263
# 100110000101000101100001		985161
# 1000101111100100110110		22f936
# 100000101010110100000		1055a0
# 100000011111101011011000		81fad8
# 11000010101001111100110		6153e6
# 11101100101100111100010		7659e2
# 1000110001010100110		462a6
# 1111011011001101111100		3db37c
# 1011001110101101001100		2ceb4c
# 100010011100110100110010		89cd32
# 11100110000001110000100		730384
# 11011011110101101001001		6deb49
# 10101100000110011101000		560ce8
# 100100000010101011001110		902ace
# 100101111110010001011000		97e458
# 1010111001011110011011		2b979b
# 101000101001110010110		145396
# 11010101001010000010101		6a9415
# 111010110001010000010		1d6282
# 1000001010000000111011		20a03b
# 1010100110100110111		54d37
# 100001101110000011011110		86e0de
# 1111000100110000100100		3c4c24
# 1110010100110001011110		394c5e
# 11010001100101011100111		68cae7
# 10000101110000111000111		42e1c7
# 11011001011101000000100		6cba04
# 11101110000001110110100		7703b4
# 100001100000100100011100		86091c
# 101001111001010001001		14f289
# 101000100001101110000		144370
# 100011000111010101011111		8c755f
# 11000111000110101010001		638d51
# 100011100010011011101000		8e26e8
# 11111001100000000		1f300
# 100000000000000011010100		8000d4
# 11010010000100011100101		6908e5
# 1000101111011000100111		22f627
# 1011110101001001010110		2f5256
# 101010001100110101001		1519a9
# 100101101010011111100000		96a7e0
# 11010001110000110011100		68e19c
# 11111001110011100100010		7ce722
# 1001011001110000010010		259c12
# 11111111111101001010010		7ffa52
# 10101010010101010000100		552a84
# 11110111001000001110111		7b9077
# 100001111000100101011111		87895f
# 100010000110111110000100		886f84
# 10010110110101101101111		4b6b6f
# 11000101100011000		18b18
# 11100100000000001001100		72004c
# 111010111101101100011		1d7b63
# 11110101110000000010000		7ae010
# 11000010000100111000101		6109c5
# 111100000011000011110		1e061e
# 11001000101001111001100		6453cc
# 1000110111001110001110		23738e
# 11001101100011110010000		66c790
# 100001111011110101110010		87bd72
# 10000001010101100001011		40ab0b
# 11011000011101101001101		6c3b4d
# 100111		27
#
# Time elapsed: 0.000582 seconds

# %%
import time

def convert_numbers(file_path):
    try:
        start_time = time.time()

        with open(file_path, 'r') as file:
            content = file.read()
            numbers = content.split()

            binary_results = []
            hex_results = []

            print("Index\tInput\t\tBinary\t\tHexadecimal")
            print("-----\t-----\t\t------\t\t------------")

            for idx, number in enumerate(numbers, start=1):
                try:
                    num = int(number)
                    binary = bin(num)[2:] #print(int(bin(-12).replace("0b", ""))) -> bin(num)[2:]
                    hexa = hex(num)[2:].upper()  # Convert letters to uppercase

                    binary_results.append(binary)
                    hex_results.append(hexa)

                    print(f"{idx}\t{num}\t\t{binary}\t\t{hexa}")
                except ValueError:
                    print(f"{idx}\tInvalid data: {number}. Skipping.")

        end_time = time.time()
        elapsed_time = end_time - start_time

        write_to_file(binary_results, hex_results, elapsed_time)

    except FileNotFoundError:
        print(f"Error: File '{file_path}' not found.")
    except Exception as e:
        print(f"An error occurred: {e}")

def write_to_file(binary_results, hex_results, elapsed_time):
    with open('/content/ConversionResults.txt', 'w') as result_file:
        result_file.write("Index\tInput\t\tBinary\t\tHexadecimal\n")
        result_file.write("-----\t-----\t\t------\t\t------------\n")
        for idx, (binary, hexa) in enumerate(zip(binary_results, hex_results), start=1):
            result_file.write(f"{idx}\t\t{int(binary, 2)}\t\t{binary}\t\t{hexa}\n")

        result_file.write(f"\nTime elapsed: {elapsed_time:.6f} seconds")

# Assuming you have a file named 'fileWithData.txt' in the Colab files section
input_file_path = '/content/TC3.txt'

# Run the conversion
convert_numbers(input_file_path)
# Out:
# Index	Input		Binary		Hexadecimal
# -----	-----		------		------------
# 1	-39		b100111		X27
# 2	-36		b100100		X24
# 3	8		1000		8
# 4	34		100010		22
# 5	17		10001		11
# 6	49		110001		31
# 7	5		101		5
# 8	39		100111		27
# 9	0		0		0
# 10	33		100001		21
# 11	12		1100		C
# 12	-6		b110		X6
# 13	27		11011		1B
# 14	-4		b100		X4
# 15	-38		b100110		X26
# 16	26		11010		1A
# 17	49		110001		31
# 18	29		11101		1D
# 19	42		101010		2A
# 20	-16		b10000		X10
# 21	-28		b11100		X1C
# 22	34		100010		22
# 23	20		10100		14
# 24	0		0		0
# 25	25		11001		19
# 26	45		101101		2D
# 27	3		11		3
# 28	-46		b101110		X2E
# 29	-46		b101110		X2E
# 30	29		11101		1D
# 31	33		100001		21
# 32	29		11101		1D
# 33	26		11010		1A
# 34	-5		b101		X5
# 35	-36		b100100		X24
# 36	12		1100		C
# 37	45		101101		2D
# 38	-50		b110010		X32
# 39	0		0		0
# 40	-6		b110		X6
# 41	-39		b100111		X27
# 42	35		100011		23
# 43	26		11010		1A
# 44	-35		b100011		X23
# 45	-42		b101010		X2A
# 46	14		1110		E
# 47	-3		b11		X3
# 48	22		10110		16
# 49	-47		b101111		X2F
# 50	12		1100		C
# 51	-17		b10001		X11
# 52	-31		b11111		X1F
# 53	-25		b11001		X19
# 54	-35		b100011		X23
# 55	-18		b10010		X12
# 56	14		1110		E
# 57	37		100101		25
# 58	-8		b1000		X8
# 59	-41		b101001		X29
# 60	-50		b110010		X32
# 61	-9		b1001		X9
# 62	2		10		2
# 63	12		1100		C
# 64	-39		b100111		X27
# 65	-17		b10001		X11
# 66	0		0		0
# 67	27		11011		1B
# 68	28		11100		1C
# 69	45		101101		2D
# 70	-44		b101100		X2C
# 71	28		11100		1C
# 72	35		100011		23
# 73	-33		b100001		X21
# 74	43		101011		2B
# 75	-4		b100		X4
# 76	23		10111		17
# 77	-49		b110001		X31
# 78	49		110001		31
# 79	-7		b111		X7
# 80	-38		b100110		X26
# 81	-45		b101101		X2D
# 82	5		101		5
# 83	-21		b10101		X15
# 84	26		11010		1A
# 85	-2		b10		X2
# 86	-24		b11000		X18
# 87	6		110		6
# 88	-45		b101101		X2D
# 89	-4		b100		X4
# 90	15		1111		F
# 91	0		0		0
# 92	-17		b10001		X11
# 93	-35		b100011		X23
# 94	43		101011		2B
# 95	45		101101		2D
# 96	-35		b100011		X23
# 97	-8		b1000		X8
# 98	28		11100		1C
# 99	47		101111		2F
# 100	34		100010		22
# 101	-24		b11000		X18
# 102	-42		b101010		X2A
# 103	-13		b1101		XD
# 104	14		1110		E
# 105	-45		b101101		X2D
# 106	-35		b100011		X23
# 107	27		11011		1B
# 108	-12		b1100		XC
# 109	-19		b10011		X13
# 110	-20		b10100		X14
# 111	-14		b1110		XE
# 112	20		10100		14
# 113	30		11110		1E
# 114	12		1100		C
# 115	-36		b100100		X24
# 116	-47		b101111		X2F
# 117	-27		b11011		X1B
# 118	-3		b11		X3
# 119	6		110		6
# 120	36		100100		24
# 121	9		1001		9
# 122	-16		b10000		X10
# 123	36		100100		24
# 124	-27		b11011		X1B
# 125	7		111		7
# 126	-6		b110		X6
# 127	-5		b101		X5
# 128	5		101		5
# 129	47		101111		2F
# 130	23		10111		17
# 131	-48		b110000		X30
# 132	-24		b11000		X18
# 133	40		101000		28
# 134	-4		b100		X4
# 135	-18		b10010		X12
# 136	-19		b10011		X13
# 137	14		1110		E
# 138	15		1111		F
# 139	1		1		1
# 140	24		11000		18
# 141	-9		b1001		X9
# 142	-50		b110010		X32
# 143	18		10010		12
# 144	15		1111		F
# 145	30		11110		1E
# 146	44		101100		2C
# 147	9		1001		9
# 148	19		10011		13
# 149	33		100001		21
# 150	41		101001		29
# 151	-24		b11000		X18
# 152	43		101011		2B
# 153	48		110000		30
# 154	-23		b10111		X17
# 155	7		111		7
# 156	28		11100		1C
# 157	8		1000		8
# 158	-2		b10		X2
# 159	37		100101		25
# 160	42		101010		2A
# 161	-17		b10001		X11
# 162	-6		b110		X6
# 163	36		100100		24
# 164	22		10110		16
# 165	27		11011		1B
# 166	31		11111		1F
# 167	-47		b101111		X2F
# 168	-43		b101011		X2B
# 169	0		0		0
# 170	27		11011		1B
# 171	30		11110		1E
# 172	12		1100		C
# 173	-15		b1111		XF
# 174	-19		b10011		X13
# 175	-42		b101010		X2A
# 176	-37		b100101		X25
# 177	31		11111		1F
# 178	-10		b1010		XA
# 179	18		10010		12
# 180	33		100001		21
# 181	-15		b1111		XF
# 182	17		10001		11
# 183	25		11001		19
# 184	-25		b11001		X19
# 185	-5		b101		X5
# 186	33		100001		21
# 187	-13		b1101		XD
# 188	33		100001		21
# 189	-10		b1010		XA
# 190	47		101111		2F
# 191	47		101111		2F
# 192	-13		b1101		XD
# 193	-32		b100000		X20
# 194	1		1		1
# 195	1		1		1
# 196	-25		b11001		X19
# 197	-33		b100001		X21
# 198	16		10000		10
# 199	17		10001		11
# 200	4		100		4
# An error occurred: invalid literal for int() with base 2: 'b100111'

# %% [markdown]
# ##**Funciona para TC1 y TC2 pero NO para decimales:**

# %%
import time

def dec_to_binary(num):
    binary_result = ""
    while num > 0:
        remainder = num % 2
        binary_result = str(remainder) + binary_result
        num = num // 2
    return binary_result if binary_result else "0"

def dec_to_hexadecimal(num):
    hex_chars = "0123456789ABCDEF"
    hex_result = ""
    while num > 0:
        remainder = num % 16
        hex_result = hex_chars[remainder] + hex_result
        num = num // 16
    return hex_result if hex_result else "0"

def convert_numbers(file_path):
    try:
        start_time = time.time()

        with open(file_path, 'r') as file:
            content = file.read()
            numbers = content.split()

            binary_results = []
            hex_results = []

            print("Index\tInput\t\tBinary\t\tHexadecimal")
            print("-----\t-----\t\t------\t\t------------")

            for idx, number in enumerate(numbers, start=1):
                try:
                    num = int(number)

                    binary = dec_to_binary(num)
                    hexadecimal = dec_to_hexadecimal(num).upper()

                    binary_results.append(binary)
                    hex_results.append(hexadecimal)

                    print(f"{idx}\t{num}\t\t{binary}\t\t{hexadecimal}")
                except ValueError:
                    print(f"{idx}\tInvalid data: {number}. Skipping.")

        end_time = time.time()
        elapsed_time = end_time - start_time

        write_to_file(binary_results, hex_results, elapsed_time)

    except FileNotFoundError:
        print(f"Error: File '{file_path}' not found.")
    except Exception as e:
        print(f"An error occurred: {e}")

def write_to_file(binary_results, hex_results, elapsed_time):
    with open('/content/ConversionResults.txt', 'w') as result_file:
        result_file.write("Index\tInput\t\tBinary\t\tHexadecimal\n")
        result_file.write("-----\t-----\t\t------\t\t------------\n")
        for idx, (binary, hexa) in enumerate(zip(binary_results, hex_results), start=1):
            result_file.write(f"{idx}\t\t{int(binary, 2)}\t\t{binary}\t\t{hexa}\n")

        result_file.write(f"\nTime elapsed: {elapsed_time:.6f} seconds")

# Assuming you have a file named 'fileWithData.txt' in the Colab files section
input_file_path = '/content/TC1_P2.txt'

# Run the conversion
convert_numbers(input_file_path)
# Out:
# Index	Input		Binary		Hexadecimal
# -----	-----		------		------------
# 1	82		1010010		52
# 2	100		1100100		64
# 3	93		1011101		5D
# 4	65		1000001		41
# 5	58		111010		3A
# 6	51		110011		33
# 7	67		1000011		43
# 8	75		1001011		4B
# 9	10		1010		A
# 10	93		1011101		5D
# 11	29		11101		1D
# 12	86		1010110		56
# 13	100		1100100		64
# 14	21		10101		15
# 15	40		101000		28
# 16	90		1011010		5A
# 17	1		1		1
# 18	100		1100100		64
# 19	0		0		0
# 20	74		1001010		4A
# 21	72		1001000		48
# 22	13		1101		D
# 23	37		100101		25
# 24	66		1000010		42
# 25	29		11101		1D
# 26	22		10110		16
# 27	61		111101		3D
# 28	38		100110		26
# 29	67		1000011		43
# 30	74		1001010		4A
# 31	89		1011001		59
# 32	77		1001101		4D
# 33	85		1010101		55
# 34	93		1011101		5D
# 35	54		110110		36
# 36	43		101011		2B
# 37	75		1001011		4B
# 38	36		100100		24
# 39	85		1010101		55
# 40	8		1000		8
# 41	86		1010110		56
# 42	1		1		1
# 43	80		1010000		50
# 44	17		10001		11
# 45	94		1011110		5E
# 46	7		111		7
# 47	94		1011110		5E
# 48	95		1011111		5F
# 49	90		1011010		5A
# 50	74		1001010		4A
# 51	48		110000		30
# 52	41		101001		29
# 53	85		1010101		55
# 54	35		100011		23
# 55	1		1		1
# 56	13		1101		D
# 57	40		101000		28
# 58	52		110100		34
# 59	95		1011111		5F
# 60	25		11001		19
# 61	54		110110		36
# 62	55		110111		37
# 63	54		110110		36
# 64	70		1000110		46
# 65	61		111101		3D
# 66	22		10110		16
# 67	76		1001100		4C
# 68	85		1010101		55
# 69	52		110100		34
# 70	87		1010111		57
# 71	54		110110		36
# 72	78		1001110		4E
# 73	45		101101		2D
# 74	62		111110		3E
# 75	57		111001		39
# 76	85		1010101		55
# 77	17		10001		11
# 78	52		110100		34
# 79	33		100001		21
# 80	57		111001		39
# 81	23		10111		17
# 82	80		1010000		50
# 83	70		1000110		46
# 84	58		111010		3A
# 85	75		1001011		4B
# 86	24		11000		18
# 87	23		10111		17
# 88	32		100000		20
# 89	95		1011111		5F
# 90	75		1001011		4B
# 91	86		1010110		56
# 92	47		101111		2F
# 93	48		110000		30
# 94	88		1011000		58
# 95	78		1001110		4E
# 96	74		1001010		4A
# 97	51		110011		33
# 98	71		1000111		47
# 99	48		110000		30
# 100	75		1001011		4B
# 101	2		10		2
# 102	27		11011		1B
# 103	81		1010001		51
# 104	96		1100000		60
# 105	50		110010		32
# 106	77		1001101		4D
# 107	75		1001011		4B
# 108	80		1010000		50
# 109	8		1000		8
# 110	6		110		6
# 111	33		100001		21
# 112	0		0		0
# 113	69		1000101		45
# 114	77		1001101		4D
# 115	60		111100		3C
# 116	87		1010111		57
# 117	84		1010100		54
# 118	71		1000111		47
# 119	51		110011		33
# 120	52		110100		34
# 121	9		1001		9
# 122	37		100101		25
# 123	61		111101		3D
# 124	36		100100		24
# 125	61		111101		3D
# 126	74		1001010		4A
# 127	42		101010		2A
# 128	5		101		5
# 129	74		1001010		4A
# 130	56		111000		38
# 131	95		1011111		5F
# 132	92		1011100		5C
# 133	89		1011001		59
# 134	84		1010100		54
# 135	78		1001110		4E
# 136	8		1000		8
# 137	40		101000		28
# 138	84		1010100		54
# 139	16		10000		10
# 140	3		11		3
# 141	29		11101		1D
# 142	90		1011010		5A
# 143	77		1001101		4D
# 144	41		101001		29
# 145	65		1000001		41
# 146	54		110110		36
# 147	88		1011000		58
# 148	49		110001		31
# 149	91		1011011		5B
# 150	55		110111		37
# 151	34		100010		22
# 152	45		101101		2D
# 153	61		111101		3D
# 154	39		100111		27
# 155	60		111100		3C
# 156	76		1001100		4C
# 157	8		1000		8
# 158	21		10101		15
# 159	4		100		4
# 160	91		1011011		5B
# 161	82		1010010		52
# 162	23		10111		17
# 163	10		1010		A
# 164	15		1111		F
# 165	86		1010110		56
# 166	17		10001		11
# 167	83		1010011		53
# 168	84		1010100		54
# 169	99		1100011		63
# 170	85		1010101		55
# 171	62		111110		3E
# 172	68		1000100		44
# 173	6		110		6
# 174	96		1100000		60
# 175	5		101		5
# 176	84		1010100		54
# 177	5		101		5
# 178	5		101		5
# 179	33		100001		21
# 180	40		101000		28
# 181	42		101010		2A
# 182	6		110		6
# 183	14		1110		E
# 184	1		1		1
# 185	69		1000101		45
# 186	29		11101		1D
# 187	43		101011		2B
# 188	58		111010		3A
# 189	12		1100		C
# 190	0		0		0
# 191	49		110001		31
# 192	16		10000		10
# 193	37		100101		25
# 194	49		110001		31
# 195	52		110100		34
# 196	62		111110		3E
# 197	50		110010		32
# 198	53		110101		35
# 199	92		1011100		5C
# 200	39		100111		27

# %%
import time

def dec_to_binary(num):
    if num < 0:
        num = 2**32 + num  # Convert to 32-bit two's complement representation

    binary_result = ""
    while num > 0:
        remainder = num % 2
        binary_result = str(remainder) + binary_result
        num = num // 2
    return binary_result if binary_result else "0"

def dec_to_hexadecimal(num):
    if num < 0:
        num = 2**32 + num  # Convert to 32-bit two's complement representation

    hex_chars = "0123456789ABCDEF"
    hex_result = ""
    while num > 0:
        remainder = num % 16
        hex_result = hex_chars[remainder] + hex_result
        num = num // 16
    return hex_result if hex_result else "0"

def convert_numbers(file_path):
    try:
        start_time = time.time()

        with open(file_path, 'r') as file:
            content = file.read()
            numbers = content.split()

            binary_results = []
            hex_results = []

            print("Index\tInput\t\tBinary\t\tHexadecimal")
            print("-----\t-----\t\t------\t\t------------")

            for idx, number in enumerate(numbers, start=1):
                try:
                    num = int(number)

                    binary = dec_to_binary(num)
                    hexadecimal = dec_to_hexadecimal(num).upper()

                    binary_results.append(binary)
                    hex_results.append(hexadecimal)

                    print(f"{idx}\t{num}\t\t{binary}\t\t{hexadecimal}")
                except ValueError:
                    print(f"{idx}\tInvalid data: {number}. Skipping.")

        end_time = time.time()
        elapsed_time = end_time - start_time

        write_to_file(binary_results, hex_results, elapsed_time)

    except FileNotFoundError:
        print(f"Error: File '{file_path}' not found.")
    except Exception as e:
        print(f"An error occurred: {e}")

def write_to_file(binary_results, hex_results, elapsed_time):
    with open('/content/ConversionResults.txt', 'w') as result_file:
        result_file.write("Index\tInput\t\tBinary\t\tHexadecimal\n")
        result_file.write("-----\t-----\t\t------\t\t------------\n")
        for idx, (binary, hexa) in enumerate(zip(binary_results, hex_results), start=1):
            result_file.write(f"{idx}\t\t{int(binary, 2)}\t\t{binary}\t\t{hexa}\n")

        result_file.write(f"\nTime elapsed: {elapsed_time:.6f} seconds")

# Assuming you have a file named 'fileWithData.txt' in the Colab files section
input_file_path = '/content/TC3.txt'

# Run the conversion
convert_numbers(input_file_path)
# Out:
# Index	Input		Binary		Hexadecimal
# -----	-----		------		------------
# 1	-39		11111111111111111111111111011001		FFFFFFD9
# 2	-36		11111111111111111111111111011100		FFFFFFDC
# 3	8		1000		8
# 4	34		100010		22
# 5	17		10001		11
# 6	49		110001		31
# 7	5		101		5
# 8	39		100111		27
# 9	0		0		0
# 10	33		100001		21
# 11	12		1100		C
# 12	-6		11111111111111111111111111111010		FFFFFFFA
# 13	27		11011		1B
# 14	-4		11111111111111111111111111111100		FFFFFFFC
# 15	-38		11111111111111111111111111011010		FFFFFFDA
# 16	26		11010		1A
# 17	49		110001		31
# 18	29		11101		1D
# 19	42		101010		2A
# 20	-16		11111111111111111111111111110000		FFFFFFF0
# 21	-28		11111111111111111111111111100100		FFFFFFE4
# 22	34		100010		22
# 23	20		10100		14
# 24	0		0		0
# 25	25		11001		19
# 26	45		101101		2D
# 27	3		11		3
# 28	-46		11111111111111111111111111010010		FFFFFFD2
# 29	-46		11111111111111111111111111010010		FFFFFFD2
# 30	29		11101		1D
# 31	33		100001		21
# 32	29		11101		1D
# 33	26		11010		1A
# 34	-5		11111111111111111111111111111011		FFFFFFFB
# 35	-36		11111111111111111111111111011100		FFFFFFDC
# 36	12		1100		C
# 37	45		101101		2D
# 38	-50		11111111111111111111111111001110		FFFFFFCE
# 39	0		0		0
# 40	-6		11111111111111111111111111111010		FFFFFFFA
# 41	-39		11111111111111111111111111011001		FFFFFFD9
# 42	35		100011		23
# 43	26		11010		1A
# 44	-35		11111111111111111111111111011101		FFFFFFDD
# 45	-42		11111111111111111111111111010110		FFFFFFD6
# 46	14		1110		E
# 47	-3		11111111111111111111111111111101		FFFFFFFD
# 48	22		10110		16
# 49	-47		11111111111111111111111111010001		FFFFFFD1
# 50	12		1100		C
# 51	-17		11111111111111111111111111101111		FFFFFFEF
# 52	-31		11111111111111111111111111100001		FFFFFFE1
# 53	-25		11111111111111111111111111100111		FFFFFFE7
# 54	-35		11111111111111111111111111011101		FFFFFFDD
# 55	-18		11111111111111111111111111101110		FFFFFFEE
# 56	14		1110		E
# 57	37		100101		25
# 58	-8		11111111111111111111111111111000		FFFFFFF8
# 59	-41		11111111111111111111111111010111		FFFFFFD7
# 60	-50		11111111111111111111111111001110		FFFFFFCE
# 61	-9		11111111111111111111111111110111		FFFFFFF7
# 62	2		10		2
# 63	12		1100		C
# 64	-39		11111111111111111111111111011001		FFFFFFD9
# 65	-17		11111111111111111111111111101111		FFFFFFEF
# 66	0		0		0
# 67	27		11011		1B
# 68	28		11100		1C
# 69	45		101101		2D
# 70	-44
# 179	18		10010		12
# 180	33		100001		21
# 181	-15		11111111111111111111111111110001		FFFFFFF1
# 182	17		10001		11
# 183	25		11001		19
# 184	-25		11111111111111111111111111100111		FFFFFFE7
# 185	-5		11111111111111111111111111111011		FFFFFFFB
# 186	33		100001		21
# 187	-13		11111111111111111111111111110011		FFFFFFF3
# 188	33		100001		21
# 189	-10		11111111111111111111111111110110		FFFFFFF6
# 190	47		101111		2F
# 191	47		101111		2F
# 192	-13		11111111111111111111111111110011		FFFFFFF3
# 193	-32		11111111111111111111111111100000		FFFFFFE0
# 194	1		1		1
# 195	1		1		1
# 196	-25		11111111111111111111111111100111		FFFFFFE7
# 197	-33		11111111111111111111111111011111		FFFFFFDF
# 198	16		10000		10
# 199	17		10001		11
# 200	4		100		4

# %%
import time

def dec_to_binary(num):
    if num < 0:
        num = 2**32 + num  # Convert to 32-bit two's complement representation

    binary_result = ""
    while num > 0:
        remainder = num % 2
        binary_result = str(remainder) + binary_result
        num = num // 2

    return binary_result

def dec_to_hexadecimal(num):
    if num < 0:
        num = 2**32 + num  # Convert to 32-bit two's complement representation

    hex_chars = "0123456789ABCDEF"
    hex_result = ""
    while num > 0:
        remainder = num % 16
        hex_result = hex_chars[remainder] + hex_result
        num = num // 16

    return hex_result.upper()

def convert_numbers(file_path):
    try:
        start_time = time.time()

        with open(file_path, 'r') as file:
            content = file.read()
            numbers = content.split()

            binary_results = []
            hex_results = []

            print("Index\tInput\t\tBinary\t\tHexadecimal")
            print("-----\t-----\t\t------\t\t------------")

            for idx, number in enumerate(numbers, start=1):
                try:
                    num = int(number)

                    binary = dec_to_binary(num)
                    hexadecimal = dec_to_hexadecimal(num)

                    binary_results.append(binary)
                    hex_results.append(hexadecimal)

                    print(f"{idx}\t{num}\t\t{binary}\t\t{hexadecimal}")
                except ValueError:
                    print(f"{idx}\tInvalid data: {number}. Skipping.")

        end_time = time.time()
        elapsed_time = end_time - start_time

        write_to_file(binary_results, hex_results, elapsed_time)

    except FileNotFoundError:
        print(f"Error: File '{file_path}' not found.")
    except Exception as e:
        print(f"An error occurred: {e}")

def write_to_file(binary_results, hex_results, elapsed_time):
    with open('/content/ConversionResults.txt', 'w') as result_file:
        result_file.write("Index\tInput\t\tBinary\t\tHexadecimal\n")
        result_file.write("-----\t-----\t\t------\t\t------------\n")
        for idx, (binary, hexa) in enumerate(zip(binary_results, hex_results), start=1):
            result_file.write(f"{idx}\t\t{int(binary, 2)}\t\t{binary}\t\t{hexa}\n")

        result_file.write(f"\nTime elapsed: {elapsed_time:.6f} seconds")

# Assuming you have a file named 'fileWithData.txt' in the Colab files section
input_file_path = '/content/TC3.txt'

# Run the conversion
convert_numbers(input_file_path)
# Out:
# Index	Input		Binary		Hexadecimal
# -----	-----		------		------------
# 1	-39		11111111111111111111111111011001		FFFFFFD9
# 2	-36		11111111111111111111111111011100		FFFFFFDC
# 3	8		1000		8
# 4	34		100010		22
# 5	17		10001		11
# 6	49		110001		31
# 7	5		101		5
# 8	39		100111		27
# 9	0
# 10	33		100001		21
# 11	12		1100		C
# 12	-6		11111111111111111111111111111010		FFFFFFFA
# 13	27		11011		1B
# 14	-4		11111111111111111111111111111100		FFFFFFFC
# 15	-38		11111111111111111111111111011010		FFFFFFDA
# 16	26		11010		1A
# 17	49		110001		31
# 18	29		11101		1D
# 19	42		101010		2A
# 20	-16		11111111111111111111111111110000		FFFFFFF0
# 21	-28		11111111111111111111111111100100		FFFFFFE4
# 22	34		100010		22
# 23	20		10100		14
# 24	0
# 25	25		11001		19
# 26	45		101101		2D
# 27	3		11		3
# 28	-46		11111111111111111111111111010010		FFFFFFD2
# 29	-46		11111111111111111111111111010010		FFFFFFD2
# 30	29		11101		1D
# 31	33		100001		21
# 32	29		11101		1D
# 33	26		11010		1A
# 34	-5		11111111111111111111111111111011		FFFFFFFB
# 35	-36		11111111111111111111111111011100		FFFFFFDC
# 36	12		1100		C
# 37	45		101101		2D
# 38	-50		11111111111111111111111111001110		FFFFFFCE
# 39	0
# 40	-6		11111111111111111111111111111010		FFFFFFFA
# 41	-39		11111111111111111111111111011001		FFFFFFD9
# 42	35		100011		23
# 43	26		11010		1A
# 44	-35		11111111111111111111111111011101		FFFFFFDD
# 45	-42		11111111111111111111111111010110		FFFFFFD6
# 46	14		1110		E
# 47	-3		11111111111111111111111111111101		FFFFFFFD
# 48	22		10110		16
# 49	-47		11111111111111111111111111010001		FFFFFFD1
# 50	12		1100		C
# 51	-17		11111111111111111111111111101111		FFFFFFEF
# 52	-31		11111111111111111111111111100001		FFFFFFE1
# 53	-25		11111111111111111111111111100111		FFFFFFE7
# 54	-35		11111111111111111111111111011101		FFFFFFDD
# 55	-18		11111111111111111111111111101110		FFFFFFEE
# 56	14		1110		E
# 57	37		100101		25
# 58	-8		11111111111111111111111111111000		FFFFFFF8
# 59	-41		11111111111111111111111111010111		FFFFFFD7
# 60	-50		11111111111111111111111111001110		FFFFFFCE
# 61	-9		11111111111111111111111111110111		FFFFFFF7
# 62	2		10		2
# 63	12		1100		C
# 64	-39		11111111111111111111111111011001		FFFFFFD9
# 65	-17		11111111111111111111111111101111		FFFFFFEF
# 66	0
# 67	27		11011		1B
# 68	28		11100		1C
# 69	45		101101		2D
# 70	-44		11111111111111111111111111010100		FFFFFFD4
# 71	28		11100		1C
# 72	35		100011		23
# 73	-33
# 190	47		101111		2F
# 191	47		101111		2F
# 192	-13		11111111111111111111111111110011		FFFFFFF3
# 193	-32		11111111111111111111111111100000		FFFFFFE0
# 194	1		1		1
# 195	1		1		1
# 196	-25		11111111111111111111111111100111		FFFFFFE7
# 197	-33		11111111111111111111111111011111		FFFFFFDF
# 198	16		10000		10
# 199	17		10001		11
# 200	4		100		4
# An error occurred: invalid literal for int() with base 2: ''

# %%
import time

def dec_to_binary(num, width=10):
    if num < 0:
        num = 2**32 + num  # Convert to 32-bit two's complement representation

    binary_result = ""
    while num > 0:
        remainder = num % 2
        binary_result = str(remainder) + binary_result
        num = num // 2

    if num < 0 and len(binary_result) < width:
        binary_result = '1' * (width - len(binary_result)) + binary_result

    return binary_result

def dec_to_hexadecimal(num, width=10):
    if num < 0:
        num = 2**32 + num  # Convert to 32-bit two's complement representation

    hex_chars = "0123456789ABCDEF"
    hex_result = ""
    while num > 0:
        remainder = num % 16
        hex_result = hex_chars[remainder] + hex_result
        num = num // 16

    if num < 0 and len(hex_result) < width:
        hex_result = 'F' * (width - len(hex_result)) + hex_result

    return hex_result.upper()

def convert_numbers(file_path):
    try:
        start_time = time.time()

        with open(file_path, 'r') as file:
            content = file.read()
            numbers = content.split()

            binary_results = []
            hex_results = []

            print("Index\tInput\t\tBinary\t\tHexadecimal")
            print("-----\t-----\t\t------\t\t------------")

            for idx, number in enumerate(numbers, start=1):
                try:
                    num = int(number)

                    binary = dec_to_binary(num)
                    hexadecimal = dec_to_hexadecimal(num)

                    binary_results.append(binary)
                    hex_results.append(hexadecimal)

                    print(f"{idx}\t{num}\t\t{binary}\t\t{hexadecimal}")
                except ValueError:
                    print(f"{idx}\tInvalid data: {number}. Skipping.")

        end_time = time.time()
        elapsed_time = end_time - start_time

        write_to_file(binary_results, hex_results, elapsed_time)

    except FileNotFoundError:
        print(f"Error: File '{file_path}' not found.")
    except Exception as e:
        print(f"An error occurred: {e}")

def write_to_file(binary_results, hex_results, elapsed_time):
    with open('/content/ConversionResults.txt', 'w') as result_file:
        result_file.write("Index\tInput\t\tBinary\t\tHexadecimal\n")
        result_file.write("-----\t-----\t\t------\t\t------------\n")
        for idx, (binary, hexa) in enumerate(zip(binary_results, hex_results), start=1):
            result_file.write(f"{idx}\t\t{int(binary, 2)}\t\t{binary}\t\t{hexa}\n")

        result_file.write(f"\nTime elapsed: {elapsed_time:.6f} seconds")

# Assuming you have a file named 'fileWithData.txt' in the Colab files section
input_file_path = '/content/TC3.txt'

# Run the conversion
convert_numbers(input_file_path)
# Out:
# Index	Input		Binary		Hexadecimal
# -----	-----		------		------------
# 1	-39		11111111111111111111111111011001		FFFFFFD9
# 2	-36		11111111111111111111111111011100		FFFFFFDC
# 3	8		1000		8
# 4	34		100010		22
# 5	17		10001		11
# 6	49		110001		31
# 7	5		101		5
# 8	39		100111		27
# 9	0
# 10	33		100001		21
# 11	12		1100		C
# 12	-6		11111111111111111111111111111010		FFFFFFFA
# 13	27		11011		1B
# 14	-4		11111111111111111111111111111100		FFFFFFFC
# 15	-38		11111111111111111111111111011010		FFFFFFDA
# 16	26		11010		1A
# 17	49		110001		31
# 18	29		11101		1D
# 19	42		101010		2A
# 20	-16		11111111111111111111111111110000		FFFFFFF0
# 21	-28		11111111111111111111111111100100		FFFFFFE4
# 22	34		100010		22
# 23	20		10100		14
# 24	0
# 25	25		11001		19
# 26	45		101101		2D
# 27	3		11		3
# 28	-46		11111111111111111111111111010010		FFFFFFD2
# 29	-46		11111111111111111111111111010010		FFFFFFD2
# 30	29		11101		1D
# 31	33		100001		21
# 32	29		11101		1D
# 33	26		11010		1A
# 34	-5		11111111111111111111111111111011		FFFFFFFB
# 35	-36		11111111111111111111111111011100		FFFFFFDC
# 36	12		1100		C
# 37	45		101101		2D
# 38	-50		11111111111111111111111111001110		FFFFFFCE
# 39	0
# 40	-6		11111111111111111111111111111010		FFFFFFFA
# 41	-39		11111111111111111111111111011001		FFFFFFD9
# 42	35		100011		23
# 43	26		11010		1A
# 44	-35		11111111111111111111111111011101		FFFFFFDD
# 45	-42		11111111111111111111111111010110		FFFFFFD6
# 46	14		1110		E
# 47	-3		11111111111111111111111111111101		FFFFFFFD
# 48	22		10110		16
# 49	-47		11111111111111111111111111010001		FFFFFFD1
# 50	12		1100		C
# 51	-17		11111111111111111111111111101111		FFFFFFEF
# 52	-31		11111111111111111111111111100001		FFFFFFE1
# 53	-25		11111111111111111111111111100111		FFFFFFE7
# 54	-35		11111111111111111111111111011101		FFFFFFDD
# 55	-18		11111111111111111111111111101110		FFFFFFEE
# 56	14		1110		E
# 57	37		100101		25
# 58	-8		11111111111111111111111111111000		FFFFFFF8
# 59	-41		11111111111111111111111111010111		FFFFFFD7
# 60	-50		11111111111111111111111111001110		FFFFFFCE
# 61	-9		11111111111111111111111111110111		FFFFFFF7
# 62	2		10		2
# 63	12		1100		C
# 64	-39		11111111111111111111111111011001		FFFFFFD9
# 65	-17		11111111111111111111111111101111		FFFFFFEF
# 66	0
# 67	27		11011		1B
# 68	28		11100		1C
# 69	45		101101		2D
# 70	-44		11111111111111111111111111010100		FFFFFFD4
# 71	28		11100		1C
# 72	35		100011		23
# 73	-33		11111111111111111111111111011111		FFFFFFDF
# 74	43		101011		2B
# 75	-4		11111111111111111111111111111100		FFFFFFFC
# 76	23		10111		17
# 77	-49		11111111111111111111111111001111		FFFFFFCF
# 78	49		110001		31
# 79	-7		11111111111111111111111111111001		FFFFFFF9
# 80	-38		11111111111111111111111111011010		FFFFFFDA
# 81	-45		11111111111111111111111111010011		FFFFFFD3
# 82	5		101		5
# 83	-21		11111111111111111111111111101011		FFFFFFEB
# 84	26		11010		1A
# 85	-2		11111111111111111111111111111110		FFFFFFFE
# 86	-24		11111111111111111111111111101000		FFFFFFE8
# 87	6		110		6
# 88	-45		11111111111111111111111111010011		FFFFFFD3
# 89	-4		11111111111111111111111111111100		FFFFFFFC
# 90	15		1111		F
# 91	0
# 92	-17		11111111111111111111111111101111		FFFFFFEF
# 93	-35		11111111111111111111111111011101		FFFFFFDD
# 94	43		101011		2B
# 95	45		101101		2D
# 96	-35
# 198	16		10000		10
# 199	17		10001		11
# 200	4		100		4
# An error occurred: invalid literal for int() with base 2: ''

# %%
import time

def dec_to_binary(num, width=10):
    if num < 0:
        num = 2**32 + num  # Convert to 32-bit two's complement representation

    binary_result = ""
    while num > 0:
        remainder = num % 2
        binary_result = str(remainder) + binary_result
        num = num // 2

    if num < 0:
        binary_result = binary_result[-width:]  # Keep only the rightmost 10 characters for negative numbers
    elif len(binary_result) < width:
        binary_result = '0' * (width - len(binary_result)) + binary_result

    return binary_result

def dec_to_hexadecimal(num, width=10):
    if num < 0:
        num = 2**32 + num  # Convert to 32-bit two's complement representation

    hex_chars = "0123456789ABCDEF"
    hex_result = ""
    while num > 0:
        remainder = num % 16
        hex_result = hex_chars[remainder] + hex_result
        num = num // 16

    if num < 0 and len(hex_result) < width:
        hex_result = 'F' * (width - len(hex_result)) + hex_result

    return hex_result.upper()

def convert_numbers(file_path):
    try:
        start_time = time.time()

        with open(file_path, 'r') as file:
            content = file.read()
            numbers = content.split()

            binary_results = []
            hex_results = []

            print("Index\tInput\t\tBinary\t\tHexadecimal")
            print("-----\t-----\t\t------\t\t------------")

            for idx, number in enumerate(numbers, start=1):
                try:
                    num = int(number)

                    binary = dec_to_binary(num)
                    hexadecimal = dec_to_hexadecimal(num)

                    binary_results.append(binary)
                    hex_results.append(hexadecimal)

                    print(f"{idx}\t{num}\t\t{binary}\t\t{hexadecimal}")
                except ValueError:
                    print(f"{idx}\tInvalid data: {number}. Skipping.")

        end_time = time.time()
        elapsed_time = end_time - start_time

        write_to_file(binary_results, hex_results, elapsed_time)

    except FileNotFoundError:
        print(f"Error: File '{file_path}' not found.")
    except Exception as e:
        print(f"An error occurred: {e}")

def write_to_file(binary_results, hex_results, elapsed_time):
    with open('/content/ConversionResults.txt', 'w') as result_file:
        result_file.write("Index\tInput\t\tBinary\t\tHexadecimal\n")
        result_file.write("-----\t-----\t\t------\t\t------------\n")
        for idx, (binary, hexa) in enumerate(zip(binary_results, hex_results), start=1):
            result_file.write(f"{idx}\t\t{int(binary, 2)}\t\t{binary}\t\t{hexa}\n")

        result_file.write(f"\nTime elapsed: {elapsed_time:.6f} seconds")

# Assuming you have a file named 'fileWithData.txt' in the Colab files section
input_file_path = '/content/TC3.txt'

# Run the conversion
convert_numbers(input_file_path)
# Out:
# Index	Input		Binary		Hexadecimal
# -----	-----		------		------------
# 1	-39		11111111111111111111111111011001		FFFFFFD9
# 2	-36		11111111111111111111111111011100		FFFFFFDC
# 3	8		0000001000		8
# 4	34		0000100010		22
# 5	17		0000010001		11
# 6	49		0000110001		31
# 7	5		0000000101		5
# 8	39		0000100111		27
# 9	0		0000000000
# 10	33		0000100001		21
# 11	12		0000001100		C
# 12	-6		11111111111111111111111111111010		FFFFFFFA
# 13	27		0000011011		1B
# 14	-4		11111111111111111111111111111100		FFFFFFFC
# 15	-38		11111111111111111111111111011010		FFFFFFDA
# 16	26		0000011010		1A
# 17	49		0000110001		31
# 18	29		0000011101		1D
# 19	42		0000101010		2A
# 20	-16		11111111111111111111111111110000		FFFFFFF0
# 21	-28		11111111111111111111111111100100		FFFFFFE4
# 22	34		0000100010		22
# 23	20		0000010100		14
# 24	0		0000000000
# 25	25		0000011001		19
# 26	45		0000101101		2D
# 27	3		0000000011		3
# 28	-46		11111111111111111111111111010010		FFFFFFD2
# 29	-46		11111111111111111111111111010010		FFFFFFD2
# 30	29		0000011101		1D
# 31	33		0000100001		21
# 32	29		0000011101		1D
# 33	26		0000011010		1A
# 34	-5		11111111111111111111111111111011		FFFFFFFB
# 35	-36		11111111111111111111111111011100		FFFFFFDC
# 36	12		0000001100		C
# 37	45		0000101101		2D
# 38	-50		11111111111111111111111111001110		FFFFFFCE
# 39	0		0000000000
# 40	-6		11111111111111111111111111111010		FFFFFFFA
# 41	-39		11111111111111111111111111011001		FFFFFFD9
# 42	35		0000100011		23
# 43	26		0000011010		1A
# 44	-35		11111111111111111111111111011101		FFFFFFDD
# 45	-42		11111111111111111111111111010110		FFFFFFD6
# 46	14		0000001110		E
# 47	-3		11111111111111111111111111111101		FFFFFFFD
# 48	22		0000010110		16
# 49	-47		11111111111111111111111111010001		FFFFFFD1
# 50	12		0000001100		C
# 51	-17		11111111111111111111111111101111		FFFFFFEF
# 52	-31		11111111111111111111111111100001		FFFFFFE1
# 53	-25		11111111111111111111111111100111		FFFFFFE7
# 54	-35		11111111111111111111111111011101		FFFFFFDD
# 55	-18		11111111111111111111111111101110		FFFFFFEE
# 56	14		0000001110		E
# 57	37		0000100101		25
# 58	-8		11111111111111111111111111111000		FFFFFFF8
# 59	-41		11111111111111111111111111010111		FFFFFFD7
# 60	-50		11111111111111111111111111001110		FFFFFFCE
# 61	-9		11111111111111111111111111110111		FFFFFFF7
# 62	2		0000000010		2
# 63	12		0000001100		C
# 64	-39		11111111111111111111111111011001		FFFFFFD9
# 65	-17		11111111111111111111111111101111		FFFFFFEF
# 66	0		0000000000
# 67	27		0000011011		1B
# 68	28		0000011100		1C
# 69	45		0000101101		2D
# 70	-44		11111111111111111111111111010100		FFFFFFD4
# 71	28		0000011100		1C
# 72	35		0000100011		23
# 73	-33		11111111111111111111111111011111		FFFFFFDF
# 74	43		0000101011		2B
# 75	-4		11111111111111111111111111111100		FFFFFFFC
# 76	23		0000010111		17
# 77	-49		11111111111111111111111111001111		FFFFFFCF
# 78	49		0000110001		31
# 79	-7		11111111111111111111111111111001		FFFFFFF9
# 80	-38		11111111111111111111111111011010		FFFFFFDA
# 81	-45		11111111111111111111111111010011		FFFFFFD3
# 82	5		0000000101		5
# 83	-21		11111111111111111111111111101011		FFFFFFEB
# 84	26		0000011010		1A
# 85	-2		11111111111111111111111111111110		FFFFFFFE
# 86	-24		11111111111111111111111111101000		FFFFFFE8
# 87	6		0000000110		6
# 88	-45		11111111111111111111111111010011		FFFFFFD3
# 89	-4		11111111111111111111111111111100		FFFFFFFC
# 90	15		0000001111		F
# 91	0		0000000000
# 92	-17		11111111111111111111111111101111		FFFFFFEF
# 93	-35		11111111111111111111111111011101		FFFFFFDD
# 94	43		0000101011		2B
# 95	45		0000101101		2D
# 96	-35		11111111111111111111111111011101		FFFFFFDD
# 97	-8		11111111111111111111111111111000		FFFFFFF8
# 98	28		0000011100		1C
# 99	47		0000101111		2F
# 100	34		0000100010		22
# 101	-24		11111111111111111111111111101000		FFFFFFE8
# 102	-42		11111111111111111111111111010110		FFFFFFD6
# 103	-13		11111111111111111111111111110011		FFFFFFF3
# 104	14		0000001110		E
# 105	-45		11111111111111111111111111010011		FFFFFFD3
# 106	-35		11111111111111111111111111011101		FFFFFFDD
# 107	27		0000011011		1B
# 108	-12		11111111111111111111111111110100		FFFFFFF4
# 109	-19		11111111111111111111111111101101		FFFFFFED
# 110	-20		11111111111111111111111111101100		FFFFFFEC
# 111	-14		11111111111111111111111111110010		FFFFFFF2
# 112	20		0000010100		14
# 113	30		0000011110		1E
# 114	12		0000001100		C
# 115	-36		11111111111111111111111111011100		FFFFFFDC
# 116	-47		11111111111111111111111111010001		FFFFFFD1
# 117	-27		11111111111111111111111111100101		FFFFFFE5
# 118	-3		11111111111111111111111111111101		FFFFFFFD
# 119	6		0000000110		6
# 120	36		0000100100		24
# 121	9		0000001001		9
# 122	-16		11111111111111111111111111110000		FFFFFFF0
# 123	36		0000100100		24
# 124	-27		11111111111111111111111111100101		FFFFFFE5
# 125	7		0000000111		7
# 126	-6		11111111111111111111111111111010		FFFFFFFA
# 127	-5		11111111111111111111111111111011		FFFFFFFB
# 128	5		0000000101		5
# 129	47		0000101111		2F
# 130	23		0000010111		17
# 131	-48		11111111111111111111111111010000		FFFFFFD0
# 132	-24		11111111111111111111111111101000		FFFFFFE8
# 133	40		0000101000		28
# 134	-4		11111111111111111111111111111100		FFFFFFFC
# 135	-18		11111111111111111111111111101110		FFFFFFEE
# 136	-19		11111111111111111111111111101101		FFFFFFED
# 137	14		0000001110		E
# 138	15		0000001111		F
# 139	1		0000000001		1
# 140	24		0000011000		18
# 141	-9		11111111111111111111111111110111		FFFFFFF7
# 142	-50		11111111111111111111111111001110		FFFFFFCE
# 143	18		0000010010		12
# 144	15		0000001111		F
# 145	30		0000011110		1E
# 146	44		0000101100		2C
# 147	9		0000001001		9
# 148	19		0000010011		13
# 149	33		0000100001		21
# 150	41		0000101001		29
# 151	-24		11111111111111111111111111101000		FFFFFFE8
# 152	43		0000101011		2B
# 153	48		0000110000		30
# 154	-23		11111111111111111111111111101001		FFFFFFE9
# 155	7		0000000111		7
# 156	28		0000011100		1C
# 157	8		0000001000		8
# 158	-2		11111111111111111111111111111110		FFFFFFFE
# 159	37		0000100101		25
# 160	42		0000101010		2A
# 161	-17		11111111111111111111111111101111		FFFFFFEF
# 162	-6		11111111111111111111111111111010		FFFFFFFA
# 163	36		0000100100		24
# 164	22		0000010110		16
# 165	27		0000011011		1B
# 166	31		0000011111		1F
# 167	-47		11111111111111111111111111010001		FFFFFFD1
# 168	-43		11111111111111111111111111010101		FFFFFFD5
# 169	0		0000000000
# 170	27		0000011011		1B
# 171	30		0000011110		1E
# 172	12		0000001100		C
# 173	-15		11111111111111111111111111110001		FFFFFFF1
# 174	-19		11111111111111111111111111101101		FFFFFFED
# 175	-42		11111111111111111111111111010110		FFFFFFD6
# 176	-37		11111111111111111111111111011011		FFFFFFDB
# 177	31		0000011111		1F
# 178	-10		11111111111111111111111111110110		FFFFFFF6
# 179	18		0000010010		12
# 180	33		0000100001		21
# 181	-15		11111111111111111111111111110001		FFFFFFF1
# 182	17		0000010001		11
# 183	25		0000011001		19
# 184	-25		11111111111111111111111111100111		FFFFFFE7
# 185	-5		11111111111111111111111111111011		FFFFFFFB
# 186	33		0000100001		21
# 187	-13		11111111111111111111111111110011		FFFFFFF3
# 188	33		0000100001		21
# 189	-10		11111111111111111111111111110110		FFFFFFF6
# 190	47		0000101111		2F
# 191	47		0000101111		2F
# 192	-13		11111111111111111111111111110011		FFFFFFF3
# 193	-32		11111111111111111111111111100000		FFFFFFE0
# 194	1		0000000001		1
# 195	1		0000000001		1
# 196	-25		11111111111111111111111111100111		FFFFFFE7
# 197	-33		11111111111111111111111111011111		FFFFFFDF
# 198	16		0000010000		10
# 199	17		0000010001		11
# 200	4		0000000100		4

# %%
import time

def dec_to_binary(num, width=10):
    if num < 0:
        num = 2**32 + num  # Convert to 32-bit two's complement representation

        binary_result = ""
        while num > 0:
            remainder = num % 2
            binary_result = str(remainder) + binary_result
            num = num // 2

        return '1' * (width - len(binary_result)) + binary_result[:width]

    return bin(num)[2:].zfill(width)

def dec_to_hexadecimal(num, width=10):
    if num < 0:
        num = 2**32 + num  # Convert to 32-bit two's complement representation

        hex_chars = "0123456789ABCDEF"
        hex_result = ""
        while num > 0:
            remainder = num % 16
            hex_result = hex_chars[remainder] + hex_result
            num = num // 16

        return 'F' * (width - len(hex_result)) + hex_result[:width]

    return hex(num)[2:].upper().zfill(width)

def convert_numbers(file_path):
    try:
        start_time = time.time()

        with open(file_path, 'r') as file:
            content = file.read()
            numbers = content.split()

            binary_results = []
            hex_results = []

            print("Index\tInput\t\tBinary\t\tHexadecimal")
            print("-----\t-----\t\t------\t\t------------")

            for idx, number in enumerate(numbers, start=1):
                try:
                    num = int(number)

                    binary = dec_to_binary(num)
                    hexadecimal = dec_to_hexadecimal(num)

                    binary_results.append(binary)
                    hex_results.append(hexadecimal)

                    print(f"{idx}\t{num}\t\t{binary}\t\t{hexadecimal}")
                except ValueError:
                    print(f"{idx}\tInvalid data: {number}. Skipping.")

        end_time = time.time()
        elapsed_time = end_time - start_time

        write_to_file(binary_results, hex_results, elapsed_time)

    except FileNotFoundError:
        print(f"Error: File '{file_path}' not found.")
    except Exception as e:
        print(f"An error occurred: {e}")

def write_to_file(binary_results, hex_results, elapsed_time):
    with open('/content/ConversionResults.txt', 'w') as result_file:
        result_file.write("Index\tInput\t\tBinary\t\tHexadecimal\n")
        result_file.write("-----\t-----\t\t------\t\t------------\n")
        for idx, (binary, hexa) in enumerate(zip(binary_results, hex_results), start=1):
            result_file.write(f"{idx}\t\t{int(binary, 2)}\t\t{binary}\t\t{hexa}\n")

        result_file.write(f"\nTime elapsed: {elapsed_time:.6f} seconds")

# Assuming you have a file named 'fileWithData.txt' in the Colab files section
input_file_path = '/content/TC3.txt'

# Run the conversion
convert_numbers(input_file_path)
# Out:
# Index	Input		Binary		Hexadecimal
# -----	-----		------		------------
# 1	-39
# 168	-43		1111111111		FFFFFFFFD5
# 169	0		0000000000		0000000000
# 170	27		0000011011		000000001B
# 171	30		0000011110		000000001E
# 172	12		0000001100		000000000C
# 173	-15		1111111111		FFFFFFFFF1
# 174	-19		1111111111		FFFFFFFFED
# 175	-42		1111111111		FFFFFFFFD6
# 176	-37		1111111111		FFFFFFFFDB
# 177	31		0000011111		000000001F
# 178	-10		1111111111		FFFFFFFFF6
# 179	18		0000010010		0000000012
# 180	33		0000100001		0000000021
# 181	-15		1111111111		FFFFFFFFF1
# 182	17		0000010001		0000000011
# 183	25		0000011001		0000000019
# 184	-25		1111111111		FFFFFFFFE7
# 185	-5		1111111111		FFFFFFFFFB
# 186	33		0000100001		0000000021
# 187	-13		1111111111		FFFFFFFFF3
# 188	33		0000100001		0000000021
# 189	-10		1111111111		FFFFFFFFF6
# 190	47		0000101111		000000002F
# 191	47		0000101111		000000002F
# 192	-13		1111111111		FFFFFFFFF3
# 193	-32		1111111111		FFFFFFFFE0
# 194	1		0000000001		0000000001
# 195	1		0000000001		0000000001
# 196	-25		1111111111		FFFFFFFFE7
# 197	-33		1111111111		FFFFFFFFDF
# 198	16		0000010000		0000000010
# 199	17		0000010001		0000000011
# 200	4		0000000100		0000000004

# %% [markdown]
# **CASI BIEN, SOLO FALLA LOS HEXADECIMALES PARA LOS NEGATIVOS**

# %%
import time

def dec_to_binary(num, width=10):
    if num < 0:
        num = 2**32 + num  # Convert to 32-bit two's complement representation

        binary_result = ""
        while num > 0:
            remainder = num % 2
            binary_result = str(remainder) + binary_result
            num = num // 2

        return binary_result[-width:]

    return bin(num)[2:]

def dec_to_hexadecimal(num, width=10):
    if num < 0:
        num = 2**32 + num  # Convert to 32-bit two's complement representation

        hex_chars = "0123456789ABCDEF"
        hex_result = ""
        while num > 0:
            remainder = num % 16
            hex_result = hex_chars[remainder] + hex_result
            num = num // 16

        return hex_result[-width:]

    return hex(num)[2:].upper()

def convert_numbers(file_path):
    try:
        start_time = time.time()

        with open(file_path, 'r') as file:
            content = file.read()
            numbers = content.split()

            binary_results = []
            hex_results = []

            print("Index\tInput\t\tBinary\t\tHexadecimal")
            print("-----\t-----\t\t------\t\t------------")

            for idx, number in enumerate(numbers, start=1):
                try:
                    num = int(number)

                    binary = dec_to_binary(num)
                    hexadecimal = dec_to_hexadecimal(num)

                    binary_results.append(binary)
                    hex_results.append(hexadecimal)

                    print(f"{idx}\t{num}\t\t{binary}\t\t{hexadecimal}")
                except ValueError:
                    print(f"{idx}\tInvalid data: {number}. Skipping.")

        end_time = time.time()
        elapsed_time = end_time - start_time

        write_to_file(binary_results, hex_results, elapsed_time)

    except FileNotFoundError:
        print(f"Error: File '{file_path}' not found.")
    except Exception as e:
        print(f"An error occurred: {e}")

def write_to_file(binary_results, hex_results, elapsed_time):
    with open('/content/ConversionResults.txt', 'w') as result_file:
        result_file.write("Index\tInput\t\tBinary\t\tHexadecimal\n")
        result_file.write("-----\t-----\t\t------\t\t------------\n")
        for idx, (binary, hexa) in enumerate(zip(binary_results, hex_results), start=1):
            result_file.write(f"{idx}\t\t{int(binary, 2)}\t\t{binary}\t\t{hexa}\n")

        result_file.write(f"\nTime elapsed: {elapsed_time:.6f} seconds")

# Assuming you have a file named 'fileWithData.txt' in the Colab files section
input_file_path = '/content/TC3.txt'

# Run the conversion
convert_numbers(input_file_path)
# Out:
# Index	Input		Binary		Hexadecimal
# -----	-----		------		------------
# 1	-39		1111011001		FFFFFFD9
# 2	-36		1111011100		FFFFFFDC
# 3	8		1000		8
# 4	34		100010		22
# 5	17		10001		11
# 6	49		110001		31
# 7	5		101		5
# 8	39		100111		27
# 9	0		0		0
# 10	33		100001		21
# 11	12		1100		C
# 12	-6		1111111010		FFFFFFFA
# 13	27		11011		1B
# 14	-4		1111111100		FFFFFFFC
# 15	-38		1111011010		FFFFFFDA
# 16	26		11010		1A
# 17	49		110001		31
# 18	29		11101		1D
# 19	42		101010		2A
# 20	-16		1111110000		FFFFFFF0
# 21	-28		1111100100		FFFFFFE4
# 22	34		100010		22
# 23	20		10100		14
# 24	0		0		0
# 25	25		11001		19
# 26	45		101101		2D
# 27	3		11		3
# 28	-46		1111010010		FFFFFFD2
# 29	-46		1111010010		FFFFFFD2
# 30	29		11101		1D
# 31	33		100001		21
# 32	29		11101		1D
# 33	26		11010		1A
# 34	-5		1111111011		FFFFFFFB
# 35	-36		1111011100		FFFFFFDC
# 36	12		1100		C
# 37	45		101101		2D
# 38	-50		1111001110		FFFFFFCE
# 39	0		0		0
# 40	-6		1111111010		FFFFFFFA
# 41	-39		1111011001		FFFFFFD9
# 42	35		100011		23
# 43	26		11010		1A
# 44	-35		1111011101		FFFFFFDD
# 45	-42		1111010110		FFFFFFD6
# 46	14		1110		E
# 47	-3		1111111101		FFFFFFFD
# 48	22		10110		16
# 49	-47		1111010001		FFFFFFD1
# 50	12		1100		C
# 51	-17		1111101111		FFFFFFEF
# 52	-31		1111100001		FFFFFFE1
# 53	-25		1111100111		FFFFFFE7
# 54	-35		1111011101		FFFFFFDD
# 55	-18		1111101110		FFFFFFEE
# 56	14		1110		E
# 57	37		100101		25
# 58	-8		1111111000		FFFFFFF8
# 59	-41		1111010111		FFFFFFD7
# 60	-50		1111001110		FFFFFFCE
# 61	-9		1111110111		FFFFFFF7
# 62	2		10		2
# 63	12		1100		C
# 64	-39		1111011001		FFFFFFD9
# 65	-17		1111101111		FFFFFFEF
# 66	0		0		0
# 67	27		11011		1B
# 68	28		11100		1C
# 69	45		101101		2D
# 70	-44		1111010100		FFFFFFD4
# 71	28		11100		1C
# 72	35		100011		23
# 73	-33		1111011111		FFFFFFDF
# 74	43		101011		2B
# 75	-4		1111111100		FFFFFFFC
# 76	23		10111		17
# 77	-49		1111001111		FFFFFFCF
# 78	49		110001		31
# 79	-7		1111111001		FFFFFFF9
# 80	-38		1111011010		FFFFFFDA
# 81	-45		1111010011		FFFFFFD3
# 82	5		101		5
# 83	-21		1111101011		FFFFFFEB
# 84	26		11010		1A
# 85	-2		1111111110		FFFFFFFE
# 86	-24		1111101000		FFFFFFE8
# 87	6		110		6
# 88	-45		1111010011		FFFFFFD3
# 89	-4		1111111100		FFFFFFFC
# 90	15		1111		F
# 91	0		0		0
# 92	-17		1111101111		FFFFFFEF
# 93	-35		1111011101		FFFFFFDD
# 94	43		101011		2B
# 95	45		101101		2D
# 96	-35		1111011101		FFFFFFDD
# 97	-8		1111111000		FFFFFFF8
# 98	28		11100		1C
# 99	47		101111		2F
# 100	34		100010		22
# 101	-24		1111101000		FFFFFFE8
# 102	-42		1111010110		FFFFFFD6
# 103	-13		1111110011		FFFFFFF3
# 104	14		1110		E
# 105	-45		1111010011		FFFFFFD3
# 106	-35		1111011101		FFFFFFDD
# 107	27		11011		1B
# 108	-12		1111110100		FFFFFFF4
# 109	-19		1111101101		FFFFFFED
# 110	-20		1111101100		FFFFFFEC
# 111	-14		1111110010		FFFFFFF2
# 112	20		10100		14
# 113	30		11110		1E
# 114	12		1100		C
# 115	-36		1111011100		FFFFFFDC
# 116	-47		1111010001		FFFFFFD1
# 117	-27		1111100101		FFFFFFE5
# 118	-3		1111111101		FFFFFFFD
# 119	6		110		6
# 120	36		100100		24
# 121	9		1001		9
# 122	-16		1111110000		FFFFFFF0
# 123	36		100100		24
# 124	-27		1111100101		FFFFFFE5
# 125	7		111		7
# 126	-6		1111111010		FFFFFFFA
# 127	-5		1111111011		FFFFFFFB
# 128	5		101		5
# 129	47		101111		2F
# 130	23		10111		17
# 131	-48		1111010000		FFFFFFD0
# 132	-24		1111101000		FFFFFFE8
# 133	40		101000		28
# 134	-4		1111111100		FFFFFFFC
# 135	-18		1111101110		FFFFFFEE
# 136	-19		1111101101		FFFFFFED
# 137	14		1110		E
# 138	15		1111		F
# 139	1		1		1
# 140	24		11000		18
# 141	-9		1111110111		FFFFFFF7
# 142	-50		1111001110		FFFFFFCE
# 143	18		10010		12
# 144	15		1111		F
# 145	30		11110		1E
# 146	44		101100		2C
# 147	9		1001		9
# 148	19		10011		13
# 149	33		100001		21
# 150	41		101001		29
# 151	-24		1111101000		FFFFFFE8
# 152	43		101011		2B
# 153	48		110000		30
# 154	-23		1111101001		FFFFFFE9
# 155	7		111		7
# 156	28		11100		1C
# 157	8		1000		8
# 158	-2		1111111110		FFFFFFFE
# 159	37		100101		25
# 160	42		101010		2A
# 161	-17		1111101111		FFFFFFEF
# 162	-6		1111111010		FFFFFFFA
# 163	36		100100		24
# 164	22		10110		16
# 165	27		11011		1B
# 166	31		11111		1F
# 167	-47		1111010001		FFFFFFD1
# 168	-43		1111010101		FFFFFFD5
# 169	0		0		0
# 170	27		11011		1B
# 171	30		11110		1E
# 172	12		1100		C
# 173	-15		1111110001		FFFFFFF1
# 174	-19		1111101101		FFFFFFED
# 175	-42		1111010110		FFFFFFD6
# 176	-37		1111011011		FFFFFFDB
# 177	31		11111		1F
# 178	-10		1111110110		FFFFFFF6
# 179	18		10010		12
# 180	33		100001		21
# 181	-15		1111110001		FFFFFFF1
# 182	17		10001		11
# 183	25		11001		19
# 184	-25		1111100111		FFFFFFE7
# 185	-5		1111111011		FFFFFFFB
# 186	33		100001		21
# 187	-13		1111110011		FFFFFFF3
# 188	33		100001		21
# 189	-10		1111110110		FFFFFFF6
# 190	47		101111		2F
# 191	47		101111		2F
# 192	-13		1111110011		FFFFFFF3
# 193	-32		1111100000		FFFFFFE0
# 194	1		1		1
# 195	1		1		1
# 196	-25		1111100111		FFFFFFE7
# 197	-33		1111011111		FFFFFFDF
# 198	16		10000		10
# 199	17		10001		11
# 200	4		100		4

# %% [markdown]
# **ESTE SÍ ES EL BUENO!!**

# %%
import time

def dec_to_binary(num, width=10):
    if num < 0:
        num = 2**32 + num  # Convert to 32-bit two's complement representation

        binary_result = ""
        while num > 0:
            remainder = num % 2
            binary_result = str(remainder) + binary_result
            num = num // 2

        return binary_result[-width:]

    return bin(num)[2:]

def dec_to_hexadecimal(num, width=10):
    if num < 0:
        num = 2**32 + num  # Convert to 32-bit two's complement representation

        hex_chars = "0123456789ABCDEF"
        hex_result = ""
        while num > 0:
            remainder = num % 16
            hex_result = hex_chars[remainder] + hex_result
            num = num // 16

        return 'F' * (width - len(hex_result)) + hex_result[-width:]

    return hex(num)[2:].upper()

def convert_numbers(file_path):
    try:
        start_time = time.time()

        with open(file_path, 'r') as file:
            content = file.read()
            numbers = content.split()

            binary_results = []
            hex_results = []

            print("Index\tInput\t\tBinary\t\tHexadecimal")
            print("-----\t-----\t\t------\t\t------------")

            for idx, number in enumerate(numbers, start=1):
                try:
                    num = int(number)

                    binary = dec_to_binary(num)
                    hexadecimal = dec_to_hexadecimal(num)

                    binary_results.append(binary)
                    hex_results.append(hexadecimal)

                    print(f"{idx}\t{num}\t\t{binary}\t\t{hexadecimal}")
                except ValueError:
                    print(f"{idx}\tInvalid data: {number}. Skipping.")

        end_time = time.time()
        elapsed_time = end_time - start_time

        write_to_file(binary_results, hex_results, elapsed_time)

    except FileNotFoundError:
        print(f"Error: File '{file_path}' not found.")
    except Exception as e:
        print(f"An error occurred: {e}")

def write_to_file(binary_results, hex_results, elapsed_time):
    with open('/content/ConversionResults.txt', 'w') as result_file:
        result_file.write("Index\tInput\t\tBinary\t\tHexadecimal\n")
        result_file.write("-----\t-----\t\t------\t\t------------\n")
        for idx, (binary, hexa) in enumerate(zip(binary_results, hex_results), start=1):
            result_file.write(f"{idx}\t\t{int(binary, 2)}\t\t{binary}\t\t{hexa}\n")

        result_file.write(f"\nTime elapsed: {elapsed_time:.6f} seconds")

# Assuming you have a file named 'fileWithData.txt' in the Colab files section
input_file_path = '/content/TC3.txt'

# Run the conversion
convert_numbers(input_file_path)
# Out:
# Index	Input		Binary		Hexadecimal
# -----	-----		------		------------
# 1	-39		1111011001		FFFFFFFFD9
# 2	-36		1111011100		FFFFFFFFDC
# 3	8		1000		8
# 4	34		100010		22
# 5	17		10001		11
# 6	49		110001		31
# 7	5		101		5
# 8	39		100111		27
# 9	0		0		0
# 10	33		100001		21
# 11	12		1100		C
# 12	-6		1111111010		FFFFFFFFFA
# 13	27		11011		1B
# 14	-4		1111111100		FFFFFFFFFC
# 15	-38		1111011010		FFFFFFFFDA
# 16	26		11010		1A
# 17	49		110001		31
# 18	29		11101		1D
# 19	42		101010		2A
# 20	-16		1111110000		FFFFFFFFF0
# 21	-28		1111100100		FFFFFFFFE4
# 22	34		100010		22
# 23	20		10100		14
# 24	0		0		0
# 25	25		11001		19
# 26	45		101101		2D
# 27	3		11		3
# 28	-46		1111010010		FFFFFFFFD2
# 29	-46		1111010010		FFFFFFFFD2
# 30	29		11101		1D
# 31	33		100001		21
# 32	29		11101		1D
# 33	26		11010		1A
# 34	-5		1111111011		FFFFFFFFFB
# 35	-36		1111011100		FFFFFFFFDC
# 36	12		1100		C
# 37	45		101101		2D
# 38	-50		1111001110		FFFFFFFFCE
# 39	0		0		0
# 40	-6		1111111010		FFFFFFFFFA
# 41	-39		1111011001		FFFFFFFFD9
# 42	35		100011		23
# 43	26		11010		1A
# 44	-35		1111011101		FFFFFFFFDD
# 45	-42		1111010110		FFFFFFFFD6
# 46	14		1110		E
# 47	-3		1111111101		FFFFFFFFFD
# 48	22		10110		16
# 49	-47		1111010001		FFFFFFFFD1
# 50	12		1100		C
# 51	-17		1111101111		FFFFFFFFEF
# 52	-31		1111100001		FFFFFFFFE1
# 53	-25		1111100111		FFFFFFFFE7
# 54	-35		1111011101		FFFFFFFFDD
# 55	-18		1111101110		FFFFFFFFEE
# 56	14		1110		E
# 57	37		100101		25
# 58	-8		1111111000		FFFFFFFFF8
# 59	-41		1111010111		FFFFFFFFD7
# 60	-50		1111001110		FFFFFFFFCE
# 61	-9		1111110111		FFFFFFFFF7
# 62	2		10		2
# 63	12		1100		C
# 64	-39		1111011001		FFFFFFFFD9
# 65	-17		1111101111		FFFFFFFFEF
# 66	0		0		0
# 67	27		11011		1B
# 68	28		11100		1C
# 69	45		101101		2D
# 70	-44		1111010100		FFFFFFFFD4
# 71	28		11100		1C
# 72	35		100011		23
# 73	-33		1111011111		FFFFFFFFDF
# 74	43		101011		2B
# 75	-4		1111111100		FFFFFFFFFC
# 76	23		10111		17
# 77	-49		1111001111		FFFFFFFFCF
# 78	49		110001		31
# 79	-7		1111111001		FFFFFFFFF9
# 80	-38		1111011010		FFFFFFFFDA
# 81	-45		1111010011		FFFFFFFFD3
# 82	5		101		5
# 83	-21		1111101011		FFFFFFFFEB
# 84	26		11010		1A
# 85	-2		1111111110		FFFFFFFFFE
# 86	-24		1111101000		FFFFFFFFE8
# 87	6		110		6
# 88	-45		1111010011		FFFFFFFFD3
# 89	-4		1111111100		FFFFFFFFFC
# 90	15		1111		F
# 91	0		0		0
# 92	-17		1111101111		FFFFFFFFEF
# 93	-35		1111011101		FFFFFFFFDD
# 94	43		101011		2B
# 95	45		101101		2D
# 96	-35		1111011101		FFFFFFFFDD
# 97	-8		1111111000		FFFFFFFFF8
# 98	28		11100		1C
# 99	47		101111		2F
# 100	34		100010		22
# 101	-24		1111101000		FFFFFFFFE8
# 102	-42		1111010110		FFFFFFFFD6
# 103	-13		1111110011		FFFFFFFFF3
# 104	14		1110		E
# 105	-45		1111010011		FFFFFFFFD3
# 106	-35		1111011101		FFFFFFFFDD
# 107	27		11011		1B
# 108	-12		1111110100		FFFFFFFFF4
# 109	-19		1111101101		FFFFFFFFED
# 110	-20		1111101100		FFFFFFFFEC
# 111	-14		1111110010		FFFFFFFFF2
# 112	20		10100		14
# 113	30		11110		1E
# 114	12		1100		C
# 115	-36		1111011100		FFFFFFFFDC
# 116	-47		1111010001		FFFFFFFFD1
# 117	-27		1111100101		FFFFFFFFE5
# 118	-3		1111111101		FFFFFFFFFD
# 119	6		110		6
# 120	36		100100		24
# 121	9		1001		9
# 122	-16		1111110000		FFFFFFFFF0
# 123	36		100100		24
# 124	-27		1111100101		FFFFFFFFE5
# 125	7		111		7
# 126	-6		1111111010		FFFFFFFFFA
# 127	-5		1111111011		FFFFFFFFFB
# 128	5		101		5
# 129	47		101111		2F
# 130	23		10111		17
# 131	-48		1111010000		FFFFFFFFD0
# 132	-24		1111101000		FFFFFFFFE8
# 133	40		101000		28
# 134	-4		1111111100		FFFFFFFFFC
# 135	-18		1111101110		FFFFFFFFEE
# 136	-19		1111101101		FFFFFFFFED
# 137	14		1110		E
# 138	15		1111		F
# 139	1		1		1
# 140	24		11000		18
# 141	-9		1111110111		FFFFFFFFF7
# 142	-50		1111001110		FFFFFFFFCE
# 143	18		10010		12
# 144	15		1111		F
# 145	30		11110		1E
# 146	44		101100		2C
# 147	9		1001		9
# 148	19		10011		13
# 149	33		100001		21
# 150	41		101001		29
# 151	-24		1111101000		FFFFFFFFE8
# 152	43		101011		2B
# 153	48		110000		30
# 154	-23		1111101001		FFFFFFFFE9
# 155	7		111		7
# 156	28		11100		1C
# 157	8		1000		8
# 158	-2		1111111110		FFFFFFFFFE
# 159	37		100101		25
# 160	42		101010		2A
# 161	-17		1111101111		FFFFFFFFEF
# 162	-6		1111111010		FFFFFFFFFA
# 163	36		100100		24
# 164	22		10110		16
# 165	27		11011		1B
# 166	31		11111		1F
# 167	-47		1111010001		FFFFFFFFD1
# 168	-43		1111010101		FFFFFFFFD5
# 169	0		0		0
# 170	27		11011		1B
# 171	30		11110		1E
# 172	12		1100		C
# 173	-15		1111110001		FFFFFFFFF1
# 174	-19		1111101101		FFFFFFFFED
# 175	-42		1111010110		FFFFFFFFD6
# 176	-37		1111011011		FFFFFFFFDB
# 177	31		11111		1F
# 178	-10		1111110110		FFFFFFFFF6
# 179	18		10010		12
# 180	33		100001		21
# 181	-15		1111110001		FFFFFFFFF1
# 182	17		10001		11
# 183	25		11001		19
# 184	-25		1111100111		FFFFFFFFE7
# 185	-5		1111111011		FFFFFFFFFB
# 186	33		100001		21
# 187	-13		1111110011		FFFFFFFFF3
# 188	33		100001		21
# 189	-10		1111110110		FFFFFFFFF6
# 190	47		101111		2F
# 191	47		101111		2F
# 192	-13		1111110011		FFFFFFFFF3
# 193	-32		1111100000		FFFFFFFFE0
# 194	1		1		1
# 195	1		1		1
# 196	-25		1111100111		FFFFFFFFE7
# 197	-33		1111011111		FFFFFFFFDF
# 198	16		10000		10
# 199	17		10001		11
# 200	4		100		4

# %% [markdown]
# ## **VERSIÓN PARA EL COMMAND PROMPT**

# %%
import time
import sys

def dec_to_binary(num, width=10):
    if num < 0:
        num = 2**32 + num  # Convert to 32-bit two's complement representation

        binary_result = ""
        while num > 0:
            remainder = num % 2
            binary_result = str(remainder) + binary_result
            num = num // 2

        return binary_result[-width:]

    return bin(num)[2:]

def dec_to_hexadecimal(num, width=10):
    if num < 0:
        num = 2**32 + num  # Convert to 32-bit two's complement representation

        hex_chars = "0123456789ABCDEF"
        hex_result = ""
        while num > 0:
            remainder = num % 16
            hex_result = hex_chars[remainder] + hex_result
            num = num // 16

        return 'F' * (width - len(hex_result)) + hex_result[-width:]

    return hex(num)[2:].upper()

def convert_numbers(file_path):
    try:
        start_time = time.time()

        with open(file_path, 'r') as file:
            content = file.read()
            numbers = content.split()

            binary_results = []
            hex_results = []

            # Print the headers to console
            print("Index\tInput\t\tBinary\t\tHexadecimal")
            print("-----\t-----\t\t------\t\t------------")

            for idx, number in enumerate(numbers, start=1):
                try:
                    num = int(number)

                    binary = dec_to_binary(num)
                    hexadecimal = dec_to_hexadecimal(num)

                    binary_results.append(binary)
                    hex_results.append(hexadecimal)

                    # Print results to console
                    print(f"{idx}\t{num}\t\t{binary}\t\t{hexadecimal}")
                except ValueError:
                    print(f"{idx}\tInvalid data: {number}. Skipping.")

        end_time = time.time()
        elapsed_time = end_time - start_time

        # Write results to file and print time elapsed to console
        write_to_file(binary_results, hex_results, elapsed_time)

    except FileNotFoundError:
        print(f"Error: File '{file_path}' not found.")
    except Exception as e:
        print(f"An error occurred: {e}")

def write_to_file(binary_results, hex_results, elapsed_time):
    with open('ConversionResults.txt', 'w') as result_file:
        result_file.write("Index\tInput\t\tBinary\t\tHexadecimal\n")
        result_file.write("-----\t-----\t\t------\t\t------------\n")
        for idx, (binary, hexa) in enumerate(zip(binary_results, hex_results), start=1):
            result_file.write(f"{idx}\t\t{int(binary, 2)}\t\t{binary}\t\t{hexa}\n")

        result_file.write(f"\nTime elapsed: {elapsed_time:.6f} seconds")

        # Print time elapsed to console
        print(f"\nTime elapsed: {elapsed_time:.6f} seconds")

# To allow running from command prompt
if __name__ == "__main__":
    if len(sys.argv) != 2:
        print("Usage: python convertNumbers.py fileWithData.txt")
        sys.exit(1)

    input_file_path = sys.argv[1]

    # Run the conversion
    convert_numbers(input_file_path)
