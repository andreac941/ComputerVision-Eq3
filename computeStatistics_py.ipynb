# %% [markdown]
# <a href="https://colab.research.google.com/github/andreac941/ComputerVision-Eq3/blob/main/computeStatistics_py.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
pip install pylint
# Out:
# Collecting pylint
#   Downloading pylint-3.0.3-py3-none-any.whl (510 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 510.6/510.6 kB 8.7 MB/s eta 0:00:00
# Requirement already satisfied: platformdirs>=2.2.0 in /usr/local/lib/python3.10/dist-packages (from pylint) (4.2.0)
# Collecting astroid<=3.1.0-dev0,>=3.0.1 (from pylint)
#   Downloading astroid-3.0.2-py3-none-any.whl (275 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 275.2/275.2 kB 30.1 MB/s eta 0:00:00
# Collecting isort!=5.13.0,<6,>=4.2.5 (from pylint)
#   Downloading isort-5.13.2-py3-none-any.whl (92 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 92.3/92.3 kB 12.2 MB/s eta 0:00:00
# Collecting mccabe<0.8,>=0.6 (from pylint)
#   Downloading mccabe-0.7.0-py2.py3-none-any.whl (7.3 kB)
# Collecting tomlkit>=0.10.1 (from pylint)
#   Downloading tomlkit-0.12.3-py3-none-any.whl (37 kB)
# Collecting dill>=0.2 (from pylint)
#   Downloading dill-0.3.8-py3-none-any.whl (116 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 116.3/116.3 kB 16.4 MB/s eta 0:00:00
# Requirement already satisfied: tomli>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from pylint) (2.0.1)
# Requirement already satisfied: typing-extensions>=4.0.0 in /usr/local/lib/python3.10/dist-packages (from astroid<=3.1.0-dev0,>=3.0.1->pylint) (4.5.0)
# Installing collected packages: tomlkit, mccabe, isort, dill, astroid, pylint
# Successfully installed astroid-3.0.2 dill-0.3.8 isort-5.13.2 mccabe-0.7.0 pylint-3.0.3 tomlkit-0.12.3

# %%
import sys
import time
import statistics

def read_file(file_path):
    try:
        with open(file_path, 'r') as file:
            data = [float(line.strip()) for line in file]
        return data
    except Exception as e:
        print(f"Error reading file: {e}")
        return None

def calculate_statistics(data):
    if data is not None:
        start_time = time.time()

        mean_value = sum(data) / len(data)
        median_value = sorted(data)[len(data) // 2] if len(data) % 2 != 0 else (sorted(data)[len(data) // 2 - 1] + sorted(data)[len(data) // 2]) / 2
        mode_value = max(set(data), key=data.count)
        variance_value = sum((x - mean_value) ** 2 for x in data) / len(data)
        std_deviation_value = variance_value ** 0.5

        end_time = time.time()
        elapsed_time = end_time - start_time

        return mean_value, median_value, mode_value, variance_value, std_deviation_value, elapsed_time
    else:
        return None

def print_results(mean, median, mode, variance, std_deviation, elapsed_time):
    print(f"Mean: {mean}")
    print(f"Median: {median}")
    print(f"Mode: {mode}")
    print(f"Variance: {variance}")
    print(f"Standard Deviation: {std_deviation}")
    print(f"Time Elapsed: {elapsed_time} seconds")

def write_results_to_file(file_path, mean, median, mode, variance, std_deviation, elapsed_time):
    with open(file_path, 'w') as result_file:
        result_file.write(f"Mean: {mean}\n")
        result_file.write(f"Median: {median}\n")
        result_file.write(f"Mode: {mode}\n")
        result_file.write(f"Variance: {variance}\n")
        result_file.write(f"Standard Deviation: {std_deviation}\n")
        result_file.write(f"Time Elapsed: {elapsed_time} seconds\n")

if __name__ == "__main__":
    if len(sys.argv) != 2:
        print("Usage: python computeStatistics.py TC1.txt")
        sys.exit(1)

    input_file_path = sys.argv[1]

    data = read_file(input_file_path)

    if data is not None:
        mean, median, mode, variance, std_deviation, elapsed_time = calculate_statistics(data)

        print_results(mean, median, mode, variance, std_deviation, elapsed_time)

        write_results_to_file("StatisticsResults.txt", mean, median, mode, variance, std_deviation, elapsed_time)
# Out:
# Usage: python computeStatistics.py TC1.txt
# An exception has occurred, use %tb to see the full traceback.
#
# SystemExit: 1

# %%
import time
import statistics

def read_file(file_content):
    try:
        data = [float(line.strip()) for line in file_content.split('\n') if line.strip()]
        return data
    except ValueError as e:
        print(f"Error reading file: {e}")
        return None

def calculate_statistics(data):
    if data is not None:
        start_time = time.time()

        mean_value = sum(data) / len(data)
        median_value = sorted(data)[len(data) // 2] if len(data) % 2 != 0 else (sorted(data)[len(data) // 2 - 1] + sorted(data)[len(data) // 2]) / 2
        mode_value = max(set(data), key=data.count)
        variance_value = sum((x - mean_value) ** 2 for x in data) / len(data)
        std_deviation_value = variance_value ** 0.5

        end_time = time.time()
        elapsed_time = end_time - start_time

        return mean_value, median_value, mode_value, variance_value, std_deviation_value, elapsed_time
    else:
        return None

def print_results(mean, median, mode, variance, std_deviation, elapsed_time):
    print(f"Mean: {mean}")
    print(f"Median: {median}")
    print(f"Mode: {mode}")
    print(f"Variance: {variance}")
    print(f"Standard Deviation: {std_deviation}")
    print(f"Time Elapsed: {elapsed_time} seconds")

def write_results_to_file(file_path, mean, median, mode, variance, std_deviation, elapsed_time):
    with open(file_path, 'w') as result_file:
        result_file.write(f"Mean: {mean}\n")
        result_file.write(f"Median: {median}\n")
        result_file.write(f"Mode: {mode}\n")
        result_file.write(f"Variance: {variance}\n")
        result_file.write(f"Standard Deviation: {std_deviation}\n")
        result_file.write(f"Time Elapsed: {elapsed_time} seconds\n")

# Simulating command-line argument
file_content = """1.2
2.5
3.8
4.1
5.4
"""

with open("TC1.txt", "r") as file:
    tc1_content = file.read()

#file_content = TC1.txt
data = read_file(tc1_content)

if data is not None:
    mean, median, mode, variance, std_deviation, elapsed_time = calculate_statistics(data)

    print_results(mean, median, mode, variance, std_deviation, elapsed_time)

    write_results_to_file("StatisticsResults.txt", mean, median, mode, variance, std_deviation, elapsed_time)
# Out:
# Mean: 250.7840161861406
# Median: 247.0
# Mode: 230.0
# Variance: 20785.369132479238
# Standard Deviation: 144.17131868884059
# Time Elapsed: 0.014069080352783203 seconds

# %%
import time
import statistics

def read_file(file_content):
    data = []
    lines = file_content.split('\n')
    for line_num, line in enumerate(lines, start=1):
        try:
            if line.strip():
                data.append(float(line.strip()))
        except ValueError as e:
            print(f"Error in line {line_num}: {e}. Skipping this line.")

    return data

def calculate_statistics(data):
    if data is not None:
        start_time = time.time()

        mean_value = sum(data) / len(data)
        median_value = sorted(data)[len(data) // 2] if len(data) % 2 != 0 else (sorted(data)[len(data) // 2 - 1] + sorted(data)[len(data) // 2]) / 2
        mode_value = max(set(data), key=data.count)
        variance_value = sum((x - mean_value) ** 2 for x in data) / len(data)
        std_deviation_value = variance_value ** 0.5

        end_time = time.time()
        elapsed_time = end_time - start_time

        return mean_value, median_value, mode_value, variance_value, std_deviation_value, elapsed_time
    else:
        return None

def print_results(mean, median, mode, variance, std_deviation, elapsed_time):
    print(f"Mean: {mean}")
    print(f"Median: {median}")
    print(f"Mode: {mode}")
    print(f"Variance: {variance}")
    print(f"Standard Deviation: {std_deviation}")
    print(f"Time Elapsed: {elapsed_time} seconds")

def write_results_to_file(file_path, mean, median, mode, variance, std_deviation, elapsed_time):
    with open(file_path, 'w') as result_file:
        result_file.write(f"Mean: {mean}\n")
        result_file.write(f"Median: {median}\n")
        result_file.write(f"Mode: {mode}\n")
        result_file.write(f"Variance: {variance}\n")
        result_file.write(f"Standard Deviation: {std_deviation}\n")
        result_file.write(f"Time Elapsed: {elapsed_time} seconds\n")

# Simulating command-line argument
file_content = """1.2
2.5
3.8
4.1
5.4
"""

with open("TC1.txt", "r") as file:
    tc1_content = file.read()

#file_content = TC1.txt
data = read_file(tc1_content)

if data is not None:
    mean, median, mode, variance, std_deviation, elapsed_time = calculate_statistics(data)

    print_results(mean, median, mode, variance, std_deviation, elapsed_time)

    write_results_to_file("StatisticsResults.txt", mean, median, mode, variance, std_deviation, elapsed_time)
# Out:
# Error in line 400: could not convert string to float: '405s'. Skipping this line.
# Mean: 241.91228070175438
# Median: 239.0
# Mode: 170.0
# Variance: 21086.30558853275
# Standard Deviation: 145.21124470416453
# Time Elapsed: 0.0029757022857666016 seconds

# %%
import time
import statistics
import re

def extract_numbers_from_string(s):
    # Extract numeric parts from a string and return them as a list of floats
    return [float(part) for part in re.findall(r'-?\d+\.?\d*', s)]

def read_file(file_content):
    data = []
    lines = file_content.split('\n')
    for line_num, line in enumerate(lines, start=1):
        try:
            if line.strip():
                # Extract numbers from the line and add them to the data
                extracted_numbers = extract_numbers_from_string(line)
                data.extend(extracted_numbers)
        except ValueError as e:
            print(f"Error in line {line_num}: {e}. Skipping this line.")

    return data

def calculate_statistics(data):
    if data is not None:
        start_time = time.time()

        mean_value = sum(data) / len(data)
        median_value = sorted(data)[len(data) // 2] if len(data) % 2 != 0 else (sorted(data)[len(data) // 2 - 1] + sorted(data)[len(data) // 2]) / 2
        mode_value = max(set(data), key=data.count)
        variance_value = sum((x - mean_value) ** 2 for x in data) / len(data)
        std_deviation_value = variance_value ** 0.5

        end_time = time.time()
        elapsed_time = end_time - start_time

        return mean_value, median_value, mode_value, variance_value, std_deviation_value, elapsed_time
    else:
        return None

def print_results(mean, median, mode, variance, std_deviation, elapsed_time):
    print(f"Mean: {mean}")
    print(f"Median: {median}")
    print(f"Mode: {mode}")
    print(f"Variance: {variance}")
    print(f"Standard Deviation: {std_deviation}")
    print(f"Time Elapsed: {elapsed_time} seconds")

def write_results_to_file(file_path, mean, median, mode, variance, std_deviation, elapsed_time):
    with open(file_path, 'w') as result_file:
        result_file.write(f"Mean: {mean}\n")
        result_file.write(f"Median: {median}\n")
        result_file.write(f"Mode: {mode}\n")
        result_file.write(f"Variance: {variance}\n")
        result_file.write(f"Standard Deviation: {std_deviation}\n")
        result_file.write(f"Time Elapsed: {elapsed_time} seconds\n")

# Simulating command-line argument
file_content = """1.2
2.5
3.8
4.1
5.4
"""

with open("TC7.txt", "r") as file:
    tc1_content = file.read()

#file_content = TC1.txt
data = read_file(tc1_content)

if data is not None:
    mean, median, mode, variance, std_deviation, elapsed_time = calculate_statistics(data)

    print_results(mean, median, mode, variance, std_deviation, elapsed_time)

    write_results_to_file("StatisticsResults.txt", mean, median, mode, variance, std_deviation, elapsed_time)
# Out:
# Mean: 2.474673954997149e+20
# Median: 2.4664097307429e+20
# Mode: 4.30461588377079e+18
# Variance: 2.0910793147136484e+40
# Standard Deviation: 1.4460564700984703e+20
# Time Elapsed: 2.2058939933776855 seconds

# %%
import time
import statistics
import re

def extract_numbers_from_string(s):
    # Extract numeric parts from a string and return them as a list of strings
    return re.findall(r'-?\d+\.?\d*', s)

def convert_to_float(num_str, line_num):
    try:
        return float(num_str)
    except ValueError as e:
        print(f"Error in line {line_num}: {e}. Skipping this part of the line: {num_str}")
        return None

def read_file(file_content):
    data = []
    lines = file_content.split('\n')
    for line_num, line in enumerate(lines, start=1):
        extracted_numbers = extract_numbers_from_string(line)
        for num_str in extracted_numbers:
            print(f"Trying to convert {num_str} in line {line_num}")
            num_float = convert_to_float(num_str, line_num)
            if num_float is not None:
                data.append(num_float)

    if not data:
        print("No valid numeric data found in the file.")

    return data

def calculate_statistics(data):
    if data is not None:
        start_time = time.time()

        mean_value = sum(data) / len(data)
        median_value = sorted(data)[len(data) // 2] if len(data) % 2 != 0 else (sorted(data)[len(data) // 2 - 1] + sorted(data)[len(data) // 2]) / 2
        mode_value = max(set(data), key=data.count)
        variance_value = sum((x - mean_value) ** 2 for x in data) / len(data)
        std_deviation_value = variance_value ** 0.5

        end_time = time.time()
        elapsed_time = end_time - start_time

        return mean_value, median_value, mode_value, variance_value, std_deviation_value, elapsed_time
    else:
        return None

def print_results(mean, median, mode, variance, std_deviation, elapsed_time):
    print(f"Mean: {mean}")
    print(f"Median: {median}")
    print(f"Mode: {mode}")
    print(f"Variance: {variance}")
    print(f"Standard Deviation: {std_deviation}")
    print(f"Time Elapsed: {elapsed_time} seconds")

def write_results_to_file(file_path, mean, median, mode, variance, std_deviation, elapsed_time):
    with open(file_path, 'w') as result_file:
        result_file.write(f"Mean: {mean}\n")
        result_file.write(f"Median: {median}\n")
        result_file.write(f"Mode: {mode}\n")
        result_file.write(f"Variance: {variance}\n")
        result_file.write(f"Standard Deviation: {std_deviation}\n")
        result_file.write(f"Time Elapsed: {elapsed_time} seconds\n")

# Simulating command-line argument
your_file_content = """1.2
2.5
3.8
4.1
5.4
invalid1
invalid2
"""

with open("TC5.txt", "r") as file:
    your_file_content = file.read()
data = read_file(your_file_content)

if data:
    mean, median, mode, variance, std_deviation, elapsed_time = calculate_statistics(data)

    print_results(mean, median, mode, variance, std_deviation, elapsed_time)

    write_results_to_file("StatisticsResults.txt", mean, median, mode, variance, std_deviation, elapsed_time)
# Out:
# Trying to convert 480 in line 1
# Trying to convert 59 in line 2
# Trying to convert 331 in line 3
# Trying to convert 416 in line 4
# Trying to convert 383 in line 6
# Trying to convert 240 in line 7
# Trying to convert 393 in line 8
# Trying to convert 342 in line 9
# Trying to convert 449 in line 10
# Trying to convert 487 in line 11
# Trying to convert 487 in line 12
# Trying to convert 156 in line 13
# Trying to convert 461 in line 14
# Trying to convert 301 in line 15
# Trying to convert 2 in line 16
# Trying to convert 467 in line 17
# Trying to convert 81 in line 18
# Trying to convert 442 in line 19
# Trying to convert 19 in line 20
    try:
        return float(num_str)
    except ValueError as e:
        print(f"Error in line {line_num}: {e}. Skipping this part of the line: {num_str}")
        return None

def read_file(file_content):
    data = []
    lines = file_content.split('\n')
    for line_num, line in enumerate(lines, start=1):
        if contains_valid_numeric_data(line):
            extracted_numbers = extract_numbers_from_string(line)
            for num_str in extracted_numbers:
                num_float = convert_to_float(num_str, line_num)
                if num_float is not None:
                    data.append(num_float)
        else:
            print(f"Error in line {line_num}: Contains non-numeric or invalid data. Skipping this line.")

    if not data:
        print("No valid numeric data found in the file.")

    return data

def calculate_statistics(data):
    if data is not None:
        start_time = time.time()

        mean_value = sum(data) / len(data)
        median_value = sorted(data)[len(data) // 2] if len(data) % 2 != 0 else (sorted(data)[len(data) // 2 - 1] + sorted(data)[len(data) // 2]) / 2
        mode_value = max(set(data), key=data.count)
        variance_value = sum((x - mean_value) ** 2 for x in data) / len(data)
        std_deviation_value = variance_value ** 0.5

        end_time = time.time()
        elapsed_time = end_time - start_time

        return mean_value, median_value, mode_value, variance_value, std_deviation_value, elapsed_time
    else:
        return None

def print_results(mean, median, mode, variance, std_deviation, elapsed_time):
    print(f"Mean: {mean}")
    print(f"Median: {median}")
    print(f"Mode: {mode}")
    print(f"Variance: {variance}")
    print(f"Standard Deviation: {std_deviation}")
    print(f"Time Elapsed: {elapsed_time} seconds")

def write_results_to_file(file_path, mean, median, mode, variance, std_deviation, elapsed_time):
    with open(file_path, 'w') as result_file:
        result_file.write(f"Mean: {mean}\n")
        result_file.write(f"Median: {median}\n")
        result_file.write(f"Mode: {mode}\n")
        result_file.write(f"Variance: {variance}\n")
        result_file.write(f"Standard Deviation: {std_deviation}\n")
        result_file.write(f"Time Elapsed: {elapsed_time} seconds\n")

# Simulating command-line argument
your_file_content = """1.2
2.5
3.8
4.1
5.4
invalid1
invalid2
"""

with open("TC1.txt", "r") as file:
    your_file_content = file.read()
data = read_file(your_file_content)

if data:
    mean, median, mode, variance, std_deviation, elapsed_time = calculate_statistics(data)

    print_results(mean, median, mode, variance, std_deviation, elapsed_time)

    write_results_to_file("StatisticsResults.txt", mean, median, mode, variance, std_deviation, elapsed_time)
# Out:
# Mean: 242.32
# Median: 239.5
# Mode: 170.0
# Variance: 21099.917599999997
# Standard Deviation: 145.25810683056557
# Time Elapsed: 0.0022568702697753906 seconds

# %%
def contains_valid_numeric_data1(line):
    # Check if a line contains valid numeric data
    return all(re.match(r'-?\d*\.?\d+', part) for part in line.split())


contains_valid_numeric_data1("11;54")
# Out:
# True

# %% [markdown]
# # **VERSION BUENA DETECTANDO ERRORES - MODA CORREGIDA - FALTA CORREGIR VARIANZA**

# %%
import time
import statistics
import re

def contains_valid_data(line):
    # Check if a line contains valid data (numeric or string)
    for part in line.split():
        try:
            float(part)
        except ValueError:
            return False
    return True

def read_file(file_content):
    data = []
    lines = file_content.split('\n')
    for line_num, line in enumerate(lines, start=1):
        if contains_valid_data(line):
            extracted_numbers = extract_numbers_from_string(line)
            for num_str in extracted_numbers:
                num_float = convert_to_float(num_str, line_num)
                if num_float is not None:
                    data.append(num_float)
        else:
            print(f"Error in line {line_num}: Contains non-numeric or invalid data. Skipping this line.")

    if not data:
        print("No valid numeric data found in the file.")

    return data

def calculate_mode(data):
    frequency_dict = {}
    for num in data:
        frequency_dict[num] = frequency_dict.get(num, 0) + 1

    max_frequency = max(frequency_dict.values())
    mode = [key for key, value in frequency_dict.items() if value == max_frequency]

    return mode[0] if mode else None

def calculate_statistics(data):
    if data is not None:
        start_time = time.time()

        #if len(data)%2  == 0:
        #len(data)/2
        mean_value = sum(data) / len(data)
        median_value = sorted(data)[len(data) // 2] if len(data) % 2 != 0 else (sorted(data)[len(data) // 2 - 1] + sorted(data)[len(data) // 2]) / 2
        mode_value = calculate_mode(data) #max(set(data), key=data.count) # sort(data)
        variance_value = sum((x - mean_value) ** 2 for x in data) / len(data)
        std_deviation_value = variance_value ** 0.5

        end_time = time.time()
        elapsed_time = end_time - start_time

        return mean_value, median_value, mode_value, variance_value, std_deviation_value, elapsed_time
    else:
        return None

def print_results(mean, median, mode, variance, std_deviation, elapsed_time):
    print(f"Mean: {mean}")
    print(f"Median: {median}")
    print(f"Mode: {mode}")
    print(f"Variance: {variance}")
    print(f"Standard Deviation: {std_deviation}")
    print(f"Time Elapsed: {elapsed_time} seconds")

def write_results_to_file(file_path, mean, median, mode, variance, std_deviation, elapsed_time):
    with open(file_path, 'w') as result_file:
        result_file.write(f"Mean: {mean}\n")
        result_file.write(f"Median: {median}\n")
        result_file.write(f"Mode: {mode}\n")
        result_file.write(f"Variance: {variance}\n")
        result_file.write(f"Standard Deviation: {std_deviation}\n")
        result_file.write(f"Time Elapsed: {elapsed_time} seconds\n")

# Simulating command-line argument
your_file_content = """1.2
2.5
3.8
4.1
5.4
invalid1
invalid2
"""

with open("TC5.txt", "r") as file:
    your_file_content = file.read()
data = read_file(your_file_content)

if data:
    mean, median, mode, variance, std_deviation, elapsed_time = calculate_statistics(data)

    print_results(mean, median, mode, variance, std_deviation, elapsed_time)

    write_results_to_file("StatisticsResults.txt", mean, median, mode, variance, std_deviation, elapsed_time)
# Out:
# Error in line 5: Contains non-numeric or invalid data. Skipping this line.
# Error in line 155: Contains non-numeric or invalid data. Skipping this line.
# Error in line 232: Contains non-numeric or invalid data. Skipping this line.
# Error in line 239: Contains non-numeric or invalid data. Skipping this line.
# Mean: 241.49511400651465
# Median: 241.0
# Mode: 393.0
# Variance: 21160.021963097748
# Standard Deviation: 145.46484786056646
# Time Elapsed: 0.0002853870391845703 seconds

# %% [markdown]
# # **VERSION BUENA DETECTANDO ERRORES - MODA CORREGIDA - VARIANZA CORREGIDA !!!!**

# %%
import time
import statistics
import re

def contains_valid_data(line):
    # Check if a line contains valid data (numeric or string)
    for part in line.split():
        try:
            float(part)
        except ValueError:
            return False
    return True

def extract_numbers_from_string(s):
    # Extract numeric parts from a string and return them as a list of strings
    return re.findall(r'-?\d+\.?\d*', s)

def convert_to_float(num_str, line_num):
    try:
        return float(num_str)
    except ValueError as e:
        print(f"Error in line {line_num}: {e}. Skipping this part of the line: {num_str}")
        return None

def read_file(file_content):
    data = []
    lines = file_content.split('\n')
    for line_num, line in enumerate(lines, start=1):
        if contains_valid_data(line):
            extracted_numbers = extract_numbers_from_string(line)
            for num_str in extracted_numbers:
                num_float = convert_to_float(num_str, line_num)
                if num_float is not None:
                    data.append(num_float)
        else:
            print(f"Error in line {line_num}: Contains non-numeric or invalid data: {line}. Skipping this line.")

    if not data:
        print("No valid numeric data found in the file.")

    return data

def calculate_mode(data):
    frequency_dict = {}
    for num in data:
        frequency_dict[num] = frequency_dict.get(num, 0) + 1

    max_frequency = max(frequency_dict.values())
    mode = [key for key, value in frequency_dict.items() if value == max_frequency]

    return mode[0] if mode else None

def calculate_statistics(data):
    if data is not None:
        start_time = time.time()

        #if len(data)%2  == 0:
        #len(data)/2
        mean_value = sum(data) / len(data)
        median_value = sorted(data)[len(data) // 2] if len(data) % 2 != 0 else (sorted(data)[len(data) // 2 - 1] + sorted(data)[len(data) // 2]) / 2
        mode_value = calculate_mode(data) #max(set(data), key=data.count) # sort(data)
        variance_value = (sum((x - mean_value) ** 2 for x in data) / (len(data)-1))  #sum((x - mean_value) ** 2 for x in data) / len(data)
        std_deviation_value = (sum((x - mean_value) ** 2 for x in data) / len(data)) ** 0.5 # variance_value ** 0.5

        end_time = time.time()
        elapsed_time = end_time - start_time

        return mean_value, median_value, mode_value, variance_value, std_deviation_value, elapsed_time
    else:
        return None

def print_results(mean, median, mode, variance, std_deviation, elapsed_time):
    print(f"Mean: {mean}")
    print(f"Median: {median}")
    print(f"Mode: {mode}")
    print(f"Variance: {variance}")
    print(f"Standard Deviation: {std_deviation}")
    print(f"Time Elapsed: {elapsed_time} seconds")

def write_results_to_file(file_path, mean, median, mode, variance, std_deviation, elapsed_time):
    with open(file_path, 'w') as result_file:
        result_file.write(f"Mean: {mean}\n")
        result_file.write(f"Median: {median}\n")
        result_file.write(f"Mode: {mode}\n")
        result_file.write(f"Variance: {variance}\n")
        result_file.write(f"Standard Deviation: {std_deviation}\n")
        result_file.write(f"Time Elapsed: {elapsed_time} seconds\n")

# Simulating command-line argument
your_file_content = """1.2
2.5
3.8
4.1
5.4
invalid1
invalid2
"""

with open("TC7.txt", "r") as file: #NO APLICA PARA CONSOLA PYTHON
    your_file_content = file.read()
data = read_file(your_file_content)

if data:
    mean, median, mode, variance, std_deviation, elapsed_time = calculate_statistics(data)

    print_results(mean, median, mode, variance, std_deviation, elapsed_time)

    write_results_to_file("StatisticsResults.txt", mean, median, mode, variance, std_deviation, elapsed_time)
# Out:
# Error in line 183: Contains non-numeric or invalid data: ABBA. Skipping this line.
# Error in line 229: Contains non-numeric or invalid data: ERROR. Skipping this line.
# Mean: 2.474673954997149e+20
# Median: 2.4664097307429e+20
# Mode: 1.57638329490099e+20
# Variance: 2.091243115380632e+40
# Standard Deviation: 1.4460564700984703e+20
# Time Elapsed: 0.012381553649902344 seconds
